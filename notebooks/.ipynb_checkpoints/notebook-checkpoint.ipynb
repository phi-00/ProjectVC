# %% [markdown]
# # GTSRB Traffic Sign Recognition with Data Augmentation

# %%
import torch
import torchvision
from torchvision.transforms import v2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
import os

import sys
sys.path.insert(1, '../util')
import vcpi_util

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)

BASE_PATH     = '..'                           
PATH_TRAIN    = f'{BASE_PATH}/images/train_images'
PATH_TEST     = f'{BASE_PATH}/images/test_images'
PATH_MODELS   = f'{BASE_PATH}/models'

BATCH_SIZE = 32
EPOCHS     = 30
RUNS       = 1
NUM_CLASSES = 43  # pastas 00000 a 00042

IMG_SIZE_CONV = 32  # GTSRB usa 32x32
IMG_SIZE_VGG = 64
# Out:
# cuda:0

# %% [markdown]
# ## Auxiliar Functions

# %%
class EarlyStopping:
    def __init__(self, patience=9, min_delta=1e-5):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.min_val_loss = float('inf')

    def __call__(self, val_loss):
        if val_loss + self.min_delta < self.min_val_loss:
            self.min_val_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter > self.patience:
                return True
        return False


def train(model, train_loader, val_loader, epochs, loss_fn, optimizer,
          scheduler, early_stopper, save_path):
    history = {'loss': [], 'accuracy': [], 'val_loss': [], 'val_acc': []}
    best_val_loss = np.inf

    for epoch in range(epochs):
        model.train()
        running_loss, correct = 0.0, 0
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            loss = loss_fn(outputs, targets)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)
            correct += (predicted == targets).sum()

        model.eval()
        val_loss, v_correct = 0.0, 0
        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                val_loss += loss_fn(outputs, targets).item() * targets.size(0)
                v_correct += (preds == targets).sum()

        old_lr = optimizer.param_groups[0]['lr']
        scheduler.step(val_loss)
        new_lr = optimizer.param_groups[0]['lr']
        if old_lr != new_lr:
            print(f'  LR: {old_lr} → {new_lr}')

        epoch_loss = running_loss / len(train_loader.dataset)
        acc        = 100 * correct / len(train_loader.dataset)
        v_acc      = 100 * v_correct / len(val_loader.dataset)
        val_loss  /= len(val_loader.dataset)

        history['loss'].append(epoch_loss)
        history['accuracy'].append(acc.cpu().numpy())
        history['val_loss'].append(val_loss)
        history['val_acc'].append(v_acc.cpu().numpy())

        print(f'Epoch {epoch:03d} | Loss: {epoch_loss:.4f} | Acc: {acc:.2f}% '
              f'| Val Loss: {val_loss:.4f} | Val Acc: {v_acc:.2f}%')

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save({'epoch': epoch, 'model': model.state_dict(),
                        'optimizer': optimizer.state_dict(),
                        'scheduler': scheduler.state_dict()}, save_path)

        if early_stopper(val_loss):
            print('Early stopping!')
            break

    print('Treino concluído.\n')
    return history


def evaluate(model, data_loader):
    model.eval()
    correct = 0
    with torch.no_grad():
        for images, targets in data_loader:
            outputs = model(images.to(device))
            _, preds = torch.max(outputs, 1)
            correct += (preds.cpu() == targets).sum()
    return (correct / len(data_loader.dataset)).item()


def run_experiment(name, transform_train, transform_test, model_name='conv_II', n_runs=RUNS):
    print(f'\n{"="*60}')
    print(f'EXPERIÊNCIA: {name}')
    print(f'{"="*60}')

    # Divisão treino/validação (80/20) a partir do train_images
    full_train = torchvision.datasets.ImageFolder(
        root=PATH_TRAIN, transform=transform_train)
    
    val_size   = int(0.2 * len(full_train))
    train_size = len(full_train) - val_size
    train_set, val_set = torch.utils.data.random_split(
        full_train, [train_size, val_size],
        generator=torch.Generator().manual_seed(42))

    val_set.dataset.transform = transform_base_vgg if model_name in ('vgg16','vgg16_tl') else transform_base

    test_set = torchvision.datasets.ImageFolder(
        root=PATH_TEST, transform=transform_test)

    train_loader = torch.utils.data.DataLoader(
        train_set, batch_size=BATCH_SIZE, shuffle=True)
    val_loader   = torch.utils.data.DataLoader(
        val_set,   batch_size=BATCH_SIZE)
    test_loader  = torch.utils.data.DataLoader(
        test_set,  batch_size=BATCH_SIZE)

    results = []
    for i in range(n_runs):
        print(f'\n--- Run {i+1}/{n_runs} ---')
        
        if model_name == 'conv_II':
            model = conv_II(NUM_CLASSES).to(device)
        elif model_name == 'vgg16':
            model = torchvision.models.vgg16()
            n_inputs = model.classifier[0].in_features
            model.classifier = torch.nn.Sequential(
                torch.nn.Linear(n_inputs, 256),
                torch.nn.ReLU(),
                torch.nn.Dropout(0.5),
                torch.nn.Linear(256, NUM_CLASSES)
            )
            model.to(device)
        elif model_name == 'vgg16_tl':
            model = torchvision.models.vgg16(weights=torchvision.models.VGG16_Weights.IMAGENET1K_V1)
            for param in model.parameters():
                param.requires_grad = False
            for layer in [model.features[24], model.features[26]]:
                for param in layer.parameters():
                    param.requires_grad = True
            n_inputs = model.classifier[0].in_features
            model.classifier = torch.nn.Sequential(
                torch.nn.Linear(n_inputs, 256),
                torch.nn.ReLU(),
                torch.nn.Dropout(0.5),
                torch.nn.Linear(256, NUM_CLASSES)
            )
            model.to(device)
        
        loss_fn    = torch.nn.CrossEntropyLoss()
        optimizer  = torch.optim.Adam(model.parameters())
        scheduler  = torch.optim.lr_scheduler.ReduceLROnPlateau(
                         optimizer, mode='min', factor=0.1, patience=3)
        early_stop = EarlyStopping(patience=9)
        save_path  = f'{PATH_MODELS}/{model_name}_{name}_run{i}.pt'

        history = train(model, train_loader, val_loader, EPOCHS,
                        loss_fn, optimizer, scheduler, early_stop, save_path)

        # Recarregar melhor checkpoint
        checkpoint = torch.load(save_path)
        model.load_state_dict(checkpoint['model'])
        acc = evaluate(model, test_loader)
        print(f'Test Accuracy (run {i}): {acc*100:.2f}%')
        results.append(acc)

    mean_acc = np.mean(results)
    std_acc  = np.std(results)
    print(f'\n→ {name}: média = {mean_acc*100:.2f}% | std = {std_acc*100:.2f}%')
    return results, mean_acc, std_acc

# %%
def build_model(model_name):
    if model_name == 'conv_II':
        return conv_II(NUM_CLASSES).to(device)
    elif model_name == 'vgg16':
        model = torchvision.models.vgg16()
        n_in = model.classifier[0].in_features
        model.classifier = torch.nn.Sequential(
            torch.nn.Linear(n_in, 256), torch.nn.ReLU(),
            torch.nn.Dropout(0.5), torch.nn.Linear(256, NUM_CLASSES)
        )
        return model.to(device)
    elif model_name == 'vgg16_tl':
        model = torchvision.models.vgg16(weights=torchvision.models.VGG16_Weights.IMAGENET1K_V1)
        for param in model.parameters():
                param.requires_grad = False
        for layer in [model.features[24], model.features[26]]:
            for param in layer.parameters():
                param.requires_grad = True
        n_in = model.classifier[0].in_features
        model.classifier = torch.nn.Sequential(
            torch.nn.Linear(n_in, 256), torch.nn.ReLU(),
            torch.nn.Dropout(0.5), torch.nn.Linear(256, NUM_CLASSES)
        )
        return model.to(device)

# %% [markdown]
# ## Dataset Analysis

# %%
from collections import Counter
import pathlib

class_counts = Counter()
for cls in sorted(os.listdir(PATH_TRAIN)):
    cls_path = os.path.join(PATH_TRAIN, cls)
    if os.path.isdir(cls_path):
        class_counts[cls] = len(list(pathlib.Path(cls_path).glob('*.ppm')))

plt.figure(figsize=(16,4))
plt.bar(class_counts.keys(), class_counts.values())
plt.title('Distribuição de imagens por classe')
plt.xlabel('Classe')
plt.ylabel('Nº de imagens')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

print(f"Classe com mais imagens:  {max(class_counts, key=class_counts.get)} ({max(class_counts.values())} imgs)")
print(f"Classe com menos imagens: {min(class_counts, key=class_counts.get)} ({min(class_counts.values())} imgs)")
# Out:
# Classe com mais imagens:  00002 (2016 imgs)
# Classe com menos imagens: 00000 (188 imgs)

# %%
transform_base = v2.Compose([
    v2.Resize((IMG_SIZE_CONV, IMG_SIZE_CONV)),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True)
])

transform_base_vgg = v2.Compose([
    v2.Resize((IMG_SIZE_VGG, IMG_SIZE_VGG)),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
train_set_visualization = torchvision.datasets.ImageFolder(
        root=PATH_TRAIN, transform=transform_base)

train_loader_visualization = torch.utils.data.DataLoader(
        train_set_visualization, batch_size=BATCH_SIZE, shuffle=True)

#images, targets = next(iter(train_loader_visualization))
#print("Batch shape: ", images.shape)

#print(targets)

class_to_idx = {}
for idx, (_, label) in enumerate(train_set_visualization.samples):
    if label not in class_to_idx:
        class_to_idx[label] = idx
    if len(class_to_idx) == NUM_CLASSES:
        break

indices = [class_to_idx[c] for c in sorted(class_to_idx)]
images  = torch.stack([train_set_visualization[i][0] for i in indices])
targets = torch.tensor(sorted(class_to_idx.keys()))
rows, cols = 5, 9
n = rows * cols

images_padded  = torch.cat([images,  images[:n - len(images)]])
targets_padded = torch.cat([targets, targets[:n - len(targets)]])

vcpi_util.show_images(rows, cols, images_padded, targets_padded,
                      train_set_visualization.classes)

# %% [markdown]
# ## Model

# %%
class conv_II(torch.nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.conv1   = torch.nn.Conv2d(3, 16, 3)
        self.bn1     = torch.nn.BatchNorm2d(16)
        self.relu1   = torch.nn.ReLU()
        self.conv2   = torch.nn.Conv2d(16, 32, 3)
        self.bn2     = torch.nn.BatchNorm2d(32)
        self.relu2   = torch.nn.ReLU()
        self.maxpool1 = torch.nn.MaxPool2d(2)
        self.conv3   = torch.nn.Conv2d(32, 48, 3)
        self.bn3     = torch.nn.BatchNorm2d(48)
        self.relu3   = torch.nn.ReLU()
        self.conv4   = torch.nn.Conv2d(48, 48, 3)
        self.bn4     = torch.nn.BatchNorm2d(48)
        self.relu4   = torch.nn.ReLU()
        self.maxpool2 = torch.nn.MaxPool2d(2)
        self.dropout = torch.nn.Dropout(p=0.5)
        self.fc1     = torch.nn.Linear(48, num_classes)

    def forward(self, x):
        x = self.relu1(self.bn1(self.conv1(x)))
        x = self.relu2(self.bn2(self.conv2(x)))
        x = self.maxpool1(x)
        x = self.relu3(self.bn3(self.conv3(x)))
        x = self.relu4(self.bn4(self.conv4(x)))
        x = self.maxpool2(x)
        x = torch.mean(x, dim=[2, 3])  
        x = self.dropout(x)
        x = self.fc1(x)
        return x

# %%
all_results = []

# %% [markdown]
# ## Experience 0 - Baseline

# %%
for model_name in ['conv_II', 'vgg16', 'vgg16_tl']:
    t_base = transform_base_vgg if model_name in ('vgg16', 'vgg16_tl') else transform_base
    _, mean, std = run_experiment(
        name='baseline',
        transform_train=t_base,
        transform_test=t_base,
        model_name=model_name
    )
    all_results.append({'Modelo': model_name, 'Experiência': 'Baseline', 'Média (%)': round(mean*100,2), 'Std (%)': round(std*100,3)})
# Out:
# ============================================================
# EXPERIÊNCIA: baseline
# ============================================================
#
# --- Run 1/1 ---
# Epoch 000 | Loss: 2.5942 | Acc: 27.18% | Val Loss: 1.8031 | Val Acc: 44.93%
# Epoch 001 | Loss: 1.6371 | Acc: 50.29% | Val Loss: 1.0850 | Val Acc: 71.61%
# Epoch 002 | Loss: 1.0841 | Acc: 67.32% | Val Loss: 0.5748 | Val Acc: 85.06%
# Epoch 003 | Loss: 0.7481 | Acc: 77.70% | Val Loss: 0.3643 | Val Acc: 91.29%
# Epoch 004 | Loss: 0.5349 | Acc: 84.53% | Val Loss: 0.2318 | Val Acc: 96.80%
# Epoch 005 | Loss: 0.4116 | Acc: 88.15% | Val Loss: 0.1370 | Val Acc: 97.23%
# Epoch 006 | Loss: 0.3307 | Acc: 90.64% | Val Loss: 0.1304 | Val Acc: 97.99%
# Epoch 007 | Loss: 0.2712 | Acc: 92.59% | Val Loss: 0.1279 | Val Acc: 97.72%
# Epoch 008 | Loss: 0.2306 | Acc: 93.39% | Val Loss: 0.0544 | Val Acc: 99.18%
# Epoch 009 | Loss: 0.2068 | Acc: 94.19% | Val Loss: 0.0739 | Val Acc: 99.02%
# Epoch 010 | Loss: 0.1839 | Acc: 94.75% | Val Loss: 0.0465 | Val Acc: 99.00%
# Epoch 011 | Loss: 0.1677 | Acc: 95.22% | Val Loss: 0.0384 | Val Acc: 99.41%
# Epoch 012 | Loss: 0.1467 | Acc: 95.94% | Val Loss: 0.0618 | Val Acc: 98.76%
# Epoch 013 | Loss: 0.1412 | Acc: 96.02% | Val Loss: 0.0348 | Val Acc: 99.29%
# Epoch 014 | Loss: 0.1251 | Acc: 96.45% | Val Loss: 0.0272 | Val Acc: 99.55%
# Epoch 015 | Loss: 0.1207 | Acc: 96.51% | Val Loss: 0.0270 | Val Acc: 99.41%
# Epoch 016 | Loss: 0.1129 | Acc: 96.79% | Val Loss: 0.0336 | Val Acc: 99.21%
# Epoch 017 | Loss: 0.1002 | Acc: 97.14% | Val Loss: 0.0308 | Val Acc: 99.31%
# Epoch 018 | Loss: 0.0964 | Acc: 97.21% | Val Loss: 0.0214 | Val Acc: 99.59%
# Epoch 019 | Loss: 0.0896 | Acc: 97.47% | Val Loss: 0.0207 | Val Acc: 99.49%
# Epoch 020 | Loss: 0.0841 | Acc: 97.64% | Val Loss: 0.0274 | Val Acc: 99.36%
# Epoch 021 | Loss: 0.0883 | Acc: 97.46% | Val Loss: 0.0229 | Val Acc: 99.56%
# Epoch 022 | Loss: 0.0790 | Acc: 97.75% | Val Loss: 0.0157 | Val Acc: 99.77%
# Epoch 023 | Loss: 0.0801 | Acc: 97.74% | Val Loss: 0.0212 | Val Acc: 99.52%
# Epoch 024 | Loss: 0.0722 | Acc: 97.84% | Val Loss: 0.0278 | Val Acc: 99.42%
# Epoch 025 | Loss: 0.0730 | Acc: 97.93% | Val Loss: 0.0213 | Val Acc: 99.56%
#   LR: 0.001 → 0.0001
# Epoch 026 | Loss: 0.0661 | Acc: 98.16% | Val Loss: 0.0178 | Val Acc: 99.73%
# Epoch 027 | Loss: 0.0486 | Acc: 98.56% | Val Loss: 0.0100 | Val Acc: 99.80%
# Epoch 028 | Loss: 0.0459 | Acc: 98.71% | Val Loss: 0.0095 | Val Acc: 99.84%
# Epoch 029 | Loss: 0.0405 | Acc: 98.95% | Val Loss: 0.0087 | Val Acc: 99.82%
# Treino concluído.
#
# Test Accuracy (run 0): 97.28%
#
# → baseline: média = 97.28% | std = 0.00%
#
# ============================================================
# EXPERIÊNCIA: baseline
# ============================================================
#
# --- Run 1/1 ---
# Epoch 000 | Loss: 3.5417 | Acc: 5.14% | Val Loss: 3.4943 | Val Acc: 6.03%
# Epoch 001 | Loss: 3.4986 | Acc: 5.63% | Val Loss: 3.4933 | Val Acc: 5.35%
# Epoch 002 | Loss: 3.4968 | Acc: 5.59% | Val Loss: 3.4905 | Val Acc: 5.63%
# Epoch 003 | Loss: 3.4939 | Acc: 5.48% | Val Loss: 3.4906 | Val Acc: 5.35%
# Epoch 004 | Loss: 3.4927 | Acc: 5.48% | Val Loss: 3.4889 | Val Acc: 5.28%
# Epoch 005 | Loss: 3.4910 | Acc: 5.75% | Val Loss: 3.4952 | Val Acc: 5.63%
# Epoch 006 | Loss: 3.4913 | Acc: 5.59% | Val Loss: 3.4876 | Val Acc: 5.35%
# Epoch 007 | Loss: 3.4899 | Acc: 5.40% | Val Loss: 3.4882 | Val Acc: 5.63%
# Epoch 008 | Loss: 3.4892 | Acc: 5.61% | Val Loss: 3.4886 | Val Acc: 5.35%
# Epoch 009 | Loss: 3.4889 | Acc: 5.72% | Val Loss: 3.4876 | Val Acc: 5.35%
#   LR: 0.001 → 0.0001
# Epoch 010 | Loss: 3.4885 | Acc: 5.47% | Val Loss: 3.4882 | Val Acc: 5.35%
# Epoch 011 | Loss: 3.4874 | Acc: 5.60% | Val Loss: 3.4874 | Val Acc: 5.35%
# Epoch 012 | Loss: 3.4870 | Acc: 5.78% | Val Loss: 3.4870 | Val Acc: 5.35%
# Epoch 013 | Loss: 3.4863 | Acc: 5.75% | Val Loss: 3.4869 | Val Acc: 5.35%
# Epoch 014 | Loss: 3.4860 | Acc: 5.73% | Val Loss: 3.4869 | Val Acc: 5.35%
# Epoch 015 | Loss: 3.4865 | Acc: 5.80% | Val Loss: 3.4868 | Val Acc: 5.35%
#   LR: 0.0001 → 1e-05
# Epoch 016 | Loss: 3.4861 | Acc: 5.86% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 017 | Loss: 3.4864 | Acc: 5.89% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 018 | Loss: 3.4861 | Acc: 5.77% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 019 | Loss: 3.4856 | Acc: 5.71% | Val Loss: 3.4867 | Val Acc: 5.35%
#   LR: 1e-05 → 1.0000000000000002e-06
# Epoch 020 | Loss: 3.4858 | Acc: 5.86% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 021 | Loss: 3.4863 | Acc: 5.76% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 022 | Loss: 3.4850 | Acc: 5.82% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 023 | Loss: 3.4859 | Acc: 5.66% | Val Loss: 3.4867 | Val Acc: 5.35%
#   LR: 1.0000000000000002e-06 → 1.0000000000000002e-07
# Epoch 024 | Loss: 3.4860 | Acc: 5.93% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 025 | Loss: 3.4858 | Acc: 5.75% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 026 | Loss: 3.4862 | Acc: 5.73% | Val Loss: 3.4867 | Val Acc: 5.35%
# Early stopping!
# Treino concluído.
#
# Test Accuracy (run 0): 5.70%
#
# → baseline: média = 5.70% | std = 0.00%
#
# ============================================================
# EXPERIÊNCIA: baseline
# ============================================================
#
# --- Run 1/1 ---
# Epoch 000 | Loss: 1.2572 | Acc: 60.77% | Val Loss: 0.5067 | Val Acc: 83.32%
# Epoch 001 | Loss: 0.4458 | Acc: 86.53% | Val Loss: 0.2350 | Val Acc: 92.66%
# Epoch 002 | Loss: 0.2444 | Acc: 93.13% | Val Loss: 0.2628 | Val Acc: 93.12%
# Epoch 003 | Loss: 0.2114 | Acc: 94.54% | Val Loss: 0.1634 | Val Acc: 95.60%
# Epoch 004 | Loss: 0.1495 | Acc: 96.28% | Val Loss: 0.2216 | Val Acc: 94.45%
# Epoch 005 | Loss: 0.1842 | Acc: 95.94% | Val Loss: 0.1666 | Val Acc: 96.28%
# Epoch 006 | Loss: 0.1212 | Acc: 97.29% | Val Loss: 0.1683 | Val Acc: 95.91%
# Epoch 007 | Loss: 0.1280 | Acc: 97.38% | Val Loss: 0.1198 | Val Acc: 96.80%
# Epoch 008 | Loss: 0.1164 | Acc: 97.68% | Val Loss: 0.1732 | Val Acc: 96.60%
# Epoch 009 | Loss: 0.1051 | Acc: 97.85% | Val Loss: 0.1266 | Val Acc: 97.35%
# Epoch 010 | Loss: 0.1434 | Acc: 97.46% | Val Loss: 0.1873 | Val Acc: 96.75%
#   LR: 0.001 → 0.0001
# Epoch 011 | Loss: 0.1391 | Acc: 97.52% | Val Loss: 0.2461 | Val Acc: 96.22%
# Epoch 012 | Loss: 0.0392 | Acc: 99.14% | Val Loss: 0.1182 | Val Acc: 98.09%
# Epoch 013 | Loss: 0.0141 | Acc: 99.66% | Val Loss: 0.1095 | Val Acc: 98.25%
# Epoch 014 | Loss: 0.0098 | Acc: 99.75% | Val Loss: 0.1091 | Val Acc: 98.51%
# Epoch 015 | Loss: 0.0045 | Acc: 99.87% | Val Loss: 0.1118 | Val Acc: 98.53%
# Epoch 016 | Loss: 0.0040 | Acc: 99.88% | Val Loss: 0.1223 | Val Acc: 98.51%
# Epoch 017 | Loss: 0.0045 | Acc: 99.89% | Val Loss: 0.1208 | Val Acc: 98.56%
#   LR: 0.0001 → 1e-05
# Epoch 018 | Loss: 0.0030 | Acc: 99.93% | Val Loss: 0.1320 | Val Acc: 98.36%
# Epoch 019 | Loss: 0.0040 | Acc: 99.91% | Val Loss: 0.1230 | Val Acc: 98.57%
# Epoch 020 | Loss: 0.0034 | Acc: 99.91% | Val Loss: 0.1225 | Val Acc: 98.61%
# Epoch 021 | Loss: 0.0019 | Acc: 99.95% | Val Loss: 0.1236 | Val Acc: 98.61%
#   LR: 1e-05 → 1.0000000000000002e-06
# Epoch 022 | Loss: 0.0027 | Acc: 99.94% | Val Loss: 0.1238 | Val Acc: 98.61%
# Epoch 023 | Loss: 0.0015 | Acc: 99.95% | Val Loss: 0.1236 | Val Acc: 98.61%
# Epoch 024 | Loss: 0.0026 | Acc: 99.94% | Val Loss: 0.1235 | Val Acc: 98.61%
# Early stopping!
# Treino concluído.
#
# Test Accuracy (run 0): 86.66%
#
# → baseline: média = 86.66% | std = 0.00%

# %% [markdown]
# ## Experience 1 - Augmentation Geométrica

# %%
transform_geo = v2.Compose([
    v2.RandomRotation(15, interpolation=v2.InterpolationMode.BILINEAR),
    v2.Resize((IMG_SIZE_CONV, IMG_SIZE_CONV)),
    v2.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True)
])

transform_geo_vgg = v2.Compose([
    v2.RandomRotation(15, interpolation=v2.InterpolationMode.BILINEAR),
    v2.Resize((IMG_SIZE_VGG, IMG_SIZE_VGG)),
    v2.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

#results_geo, mean_geo, std_geo = run_experiment(
#    name='aug_geometrica',
#    transform_train=transform_geo,
#    transform_test=transform_base
#)

for model_name in ['conv_II', 'vgg16', 'vgg16_tl']:
    t_base = transform_base_vgg if model_name in ('vgg16', 'vgg16_tl') else transform_base
    t_train = transform_geo_vgg if model_name in ('vgg16', 'vgg16_tl') else transform_geo
    _, mean, std = run_experiment(
        name='geo',
        transform_train=t_train,
        transform_test=t_base,
        model_name=model_name
    )
    all_results.append({'Modelo': model_name, 'Experiência': 'Geométrica', 'Média (%)': round(mean*100,2), 'Std (%)': round(std*100,3)})
# Out:
# ============================================================
# EXPERIÊNCIA: geo
# ============================================================
#
# --- Run 1/1 ---
# Epoch 000 | Loss: 2.5193 | Acc: 29.46% | Val Loss: 1.7151 | Val Acc: 52.95%
# Epoch 001 | Loss: 1.5867 | Acc: 51.85% | Val Loss: 1.1498 | Val Acc: 67.59%
# Epoch 002 | Loss: 1.0619 | Acc: 68.20% | Val Loss: 0.5769 | Val Acc: 86.11%
# Epoch 003 | Loss: 0.7404 | Acc: 78.12% | Val Loss: 0.3053 | Val Acc: 94.91%
# Epoch 004 | Loss: 0.5397 | Acc: 84.42% | Val Loss: 0.2266 | Val Acc: 94.85%
# Epoch 005 | Loss: 0.4107 | Acc: 88.25% | Val Loss: 0.2075 | Val Acc: 96.66%
# Epoch 006 | Loss: 0.3264 | Acc: 90.67% | Val Loss: 0.0997 | Val Acc: 98.54%
# Epoch 007 | Loss: 0.2777 | Acc: 92.19% | Val Loss: 0.0885 | Val Acc: 98.44%
# Epoch 008 | Loss: 0.2261 | Acc: 93.55% | Val Loss: 0.0603 | Val Acc: 99.11%
# Epoch 009 | Loss: 0.2061 | Acc: 94.18% | Val Loss: 0.0655 | Val Acc: 98.94%
# Epoch 010 | Loss: 0.1919 | Acc: 94.45% | Val Loss: 0.0577 | Val Acc: 98.88%
# Epoch 011 | Loss: 0.1663 | Acc: 95.17% | Val Loss: 0.0387 | Val Acc: 99.42%
# Epoch 012 | Loss: 0.1498 | Acc: 95.75% | Val Loss: 0.0384 | Val Acc: 99.34%
# Epoch 013 | Loss: 0.1360 | Acc: 96.21% | Val Loss: 0.0279 | Val Acc: 99.46%
# Epoch 014 | Loss: 0.1291 | Acc: 96.27% | Val Loss: 0.0387 | Val Acc: 99.28%
# Epoch 015 | Loss: 0.1216 | Acc: 96.52% | Val Loss: 0.0241 | Val Acc: 99.39%
# Epoch 016 | Loss: 0.1091 | Acc: 97.00% | Val Loss: 0.0383 | Val Acc: 99.49%
# Epoch 017 | Loss: 0.1054 | Acc: 96.97% | Val Loss: 0.0293 | Val Acc: 99.49%
# Epoch 018 | Loss: 0.0966 | Acc: 97.23% | Val Loss: 0.0193 | Val Acc: 99.65%
# Epoch 019 | Loss: 0.0972 | Acc: 97.16% | Val Loss: 0.0216 | Val Acc: 99.53%
# Epoch 020 | Loss: 0.0907 | Acc: 97.40% | Val Loss: 0.0171 | Val Acc: 99.53%
# Epoch 021 | Loss: 0.0823 | Acc: 97.59% | Val Loss: 0.0141 | Val Acc: 99.77%
# Epoch 022 | Loss: 0.0883 | Acc: 97.52% | Val Loss: 0.0174 | Val Acc: 99.72%
# Epoch 023 | Loss: 0.0749 | Acc: 97.86% | Val Loss: 0.0137 | Val Acc: 99.77%
# Epoch 024 | Loss: 0.0771 | Acc: 97.80% | Val Loss: 0.0162 | Val Acc: 99.58%
# Epoch 025 | Loss: 0.0735 | Acc: 97.88% | Val Loss: 0.0166 | Val Acc: 99.73%
# Epoch 026 | Loss: 0.0688 | Acc: 97.97% | Val Loss: 0.0143 | Val Acc: 99.76%
# Epoch 027 | Loss: 0.0688 | Acc: 97.93% | Val Loss: 0.0130 | Val Acc: 99.70%
# Epoch 028 | Loss: 0.0630 | Acc: 98.20% | Val Loss: 0.0340 | Val Acc: 99.28%
# Epoch 029 | Loss: 0.0687 | Acc: 97.95% | Val Loss: 0.0140 | Val Acc: 99.75%
# Treino concluído.
#
# Test Accuracy (run 0): 96.60%
#
# → geo: média = 96.60% | std = 0.00%
#
# ============================================================
# EXPERIÊNCIA: geo
# ============================================================
#
# --- Run 1/1 ---
# Epoch 000 | Loss: 3.5552 | Acc: 5.33% | Val Loss: 3.4952 | Val Acc: 5.35%
# Epoch 001 | Loss: 3.4991 | Acc: 5.82% | Val Loss: 3.4892 | Val Acc: 5.63%
# Epoch 002 | Loss: 3.4979 | Acc: 5.24% | Val Loss: 3.4906 | Val Acc: 5.28%
# Epoch 003 | Loss: 3.4941 | Acc: 5.59% | Val Loss: 3.4886 | Val Acc: 5.63%
# Epoch 004 | Loss: 3.4948 | Acc: 5.74% | Val Loss: 3.4916 | Val Acc: 5.35%
# Epoch 005 | Loss: 3.4921 | Acc: 5.56% | Val Loss: 3.4874 | Val Acc: 6.03%
# Epoch 006 | Loss: 3.4916 | Acc: 5.68% | Val Loss: 3.4884 | Val Acc: 5.35%
# Epoch 007 | Loss: 3.4910 | Acc: 5.52% | Val Loss: 3.4886 | Val Acc: 5.35%
# Epoch 008 | Loss: 3.4900 | Acc: 5.55% | Val Loss: 3.4869 | Val Acc: 5.63%
# Epoch 009 | Loss: 3.4892 | Acc: 5.89% | Val Loss: 3.4885 | Val Acc: 5.35%
# Epoch 010 | Loss: 3.4888 | Acc: 5.47% | Val Loss: 3.4876 | Val Acc: 5.63%
# Epoch 011 | Loss: 3.4888 | Acc: 5.65% | Val Loss: 3.4876 | Val Acc: 5.35%
#   LR: 0.001 → 0.0001
# Epoch 012 | Loss: 3.4884 | Acc: 5.83% | Val Loss: 3.4874 | Val Acc: 6.03%
# Epoch 013 | Loss: 3.4867 | Acc: 5.44% | Val Loss: 3.4868 | Val Acc: 6.03%
# Epoch 014 | Loss: 3.4867 | Acc: 5.48% | Val Loss: 3.4868 | Val Acc: 5.35%
# Epoch 015 | Loss: 3.4865 | Acc: 5.72% | Val Loss: 3.4867 | Val Acc: 5.35%
#   LR: 0.0001 → 1e-05
# Epoch 016 | Loss: 3.4858 | Acc: 5.67% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 017 | Loss: 3.4866 | Acc: 5.80% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 018 | Loss: 3.4861 | Acc: 5.73% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 019 | Loss: 3.4866 | Acc: 5.57% | Val Loss: 3.4867 | Val Acc: 5.35%
#   LR: 1e-05 → 1.0000000000000002e-06
# Epoch 020 | Loss: 3.4867 | Acc: 5.73% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 021 | Loss: 3.4856 | Acc: 5.75% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 022 | Loss: 3.4859 | Acc: 5.65% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 023 | Loss: 3.4862 | Acc: 5.59% | Val Loss: 3.4867 | Val Acc: 5.35%
#   LR: 1.0000000000000002e-06 → 1.0000000000000002e-07
# Epoch 024 | Loss: 3.4856 | Acc: 5.66% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 025 | Loss: 3.4859 | Acc: 5.94% | Val Loss: 3.4867 | Val Acc: 5.35%
# Early stopping!
# Treino concluído.
#
# Test Accuracy (run 0): 5.70%
#
# → geo: média = 5.70% | std = 0.00%
#
# ============================================================
# EXPERIÊNCIA: geo
# ============================================================
#
# --- Run 1/1 ---
# Epoch 000 | Loss: 1.2164 | Acc: 61.57% | Val Loss: 0.5751 | Val Acc: 80.66%
# Epoch 001 | Loss: 0.4290 | Acc: 86.36% | Val Loss: 0.2653 | Val Acc: 91.27%
# Epoch 002 | Loss: 0.2851 | Acc: 91.59% | Val Loss: 0.2495 | Val Acc: 92.86%
# Epoch 003 | Loss: 0.1880 | Acc: 94.88% | Val Loss: 0.2051 | Val Acc: 94.74%
# Epoch 004 | Loss: 0.1466 | Acc: 96.28% | Val Loss: 0.2108 | Val Acc: 95.63%
# Epoch 005 | Loss: 0.1595 | Acc: 96.50% | Val Loss: 0.2397 | Val Acc: 95.28%
# Epoch 006 | Loss: 0.1856 | Acc: 96.52% | Val Loss: 0.3516 | Val Acc: 92.30%
#   LR: 0.001 → 0.0001
# Epoch 007 | Loss: 0.1273 | Acc: 97.51% | Val Loss: 0.2309 | Val Acc: 95.70%
# Epoch 008 | Loss: 0.0432 | Acc: 99.07% | Val Loss: 0.0931 | Val Acc: 98.19%
# Epoch 009 | Loss: 0.0150 | Acc: 99.69% | Val Loss: 0.0848 | Val Acc: 98.43%
# Epoch 010 | Loss: 0.0074 | Acc: 99.82% | Val Loss: 0.0822 | Val Acc: 98.46%
# Epoch 011 | Loss: 0.0044 | Acc: 99.88% | Val Loss: 0.0856 | Val Acc: 98.57%
# Epoch 012 | Loss: 0.0042 | Acc: 99.90% | Val Loss: 0.0956 | Val Acc: 98.42%
# Epoch 013 | Loss: 0.0030 | Acc: 99.93% | Val Loss: 0.0882 | Val Acc: 98.57%
#   LR: 0.0001 → 1e-05
# Epoch 014 | Loss: 0.0026 | Acc: 99.95% | Val Loss: 0.0915 | Val Acc: 98.61%
# Epoch 015 | Loss: 0.0029 | Acc: 99.93% | Val Loss: 0.0874 | Val Acc: 98.81%
# Epoch 016 | Loss: 0.0016 | Acc: 99.96% | Val Loss: 0.0875 | Val Acc: 98.80%
# Epoch 017 | Loss: 0.0014 | Acc: 99.97% | Val Loss: 0.0884 | Val Acc: 98.84%
#   LR: 1e-05 → 1.0000000000000002e-06
# Epoch 018 | Loss: 0.0023 | Acc: 99.95% | Val Loss: 0.0898 | Val Acc: 98.70%
# Epoch 019 | Loss: 0.0011 | Acc: 99.96% | Val Loss: 0.0895 | Val Acc: 98.71%
# Epoch 020 | Loss: 0.0012 | Acc: 99.96% | Val Loss: 0.0894 | Val Acc: 98.70%
# Early stopping!
# Treino concluído.
#
# Test Accuracy (run 0): 88.07%
#
# → geo: média = 88.07% | std = 0.00%

# %% [markdown]
# ## Experience 2 - Augmentation Geométrica 2

# %%
transform_geo2 = v2.Compose([
    v2.RandomPerspective(distortion_scale=0.2, p=0.6),
    v2.Resize((IMG_SIZE_CONV +8, IMG_SIZE_CONV +8)),
    v2.RandomCrop((IMG_SIZE_CONV, IMG_SIZE_CONV)),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True)
])

transform_geo2_vgg = v2.Compose([
    v2.RandomPerspective(distortion_scale=0.2, p=0.6),
    v2.Resize((IMG_SIZE_VGG +8, IMG_SIZE_VGG +8)),
    v2.RandomCrop((IMG_SIZE_VGG, IMG_SIZE_VGG)),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

#results_geo2, mean_geo2, std_geo2 = run_experiment(
#    name='aug_geometrica2',
#    transform_train=transform_geo2,
#    transform_test=transform_base
#)

for model_name in ['conv_II', 'vgg16', 'vgg16_tl']:
    t_base = transform_base_vgg if model_name in ('vgg16', 'vgg16_tl') else transform_base
    t_train = transform_geo2_vgg if model_name in ('vgg16', 'vgg16_tl') else transform_geo2
    _, mean, std = run_experiment(
        name='geo2',
        transform_train=t_train,
        transform_test=t_base,
        model_name=model_name
    )
    all_results.append({'Modelo': model_name, 'Experiência': 'Geométrica 2', 'Média (%)': round(mean*100,2), 'Std (%)': round(std*100,3)})
# Out:
# ============================================================
# EXPERIÊNCIA: geo2
# ============================================================
#
# --- Run 1/1 ---
# Epoch 000 | Loss: 2.5198 | Acc: 30.02% | Val Loss: 1.6757 | Val Acc: 53.30%
# Epoch 001 | Loss: 1.5450 | Acc: 54.02% | Val Loss: 1.0127 | Val Acc: 71.83%
# Epoch 002 | Loss: 1.0337 | Acc: 69.27% | Val Loss: 0.5564 | Val Acc: 87.06%
# Epoch 003 | Loss: 0.7132 | Acc: 79.26% | Val Loss: 0.3551 | Val Acc: 93.66%
# Epoch 004 | Loss: 0.5245 | Acc: 84.70% | Val Loss: 0.1591 | Val Acc: 97.18%
# Epoch 005 | Loss: 0.4082 | Acc: 88.37% | Val Loss: 0.1573 | Val Acc: 97.76%
# Epoch 006 | Loss: 0.3189 | Acc: 90.84% | Val Loss: 0.0831 | Val Acc: 98.71%
# Epoch 007 | Loss: 0.2694 | Acc: 92.44% | Val Loss: 0.0584 | Val Acc: 99.14%
# Epoch 008 | Loss: 0.2278 | Acc: 93.53% | Val Loss: 0.1063 | Val Acc: 98.06%
# Epoch 009 | Loss: 0.2064 | Acc: 94.11% | Val Loss: 0.0628 | Val Acc: 98.80%
# Epoch 010 | Loss: 0.1809 | Acc: 94.90% | Val Loss: 0.0654 | Val Acc: 98.74%
# Epoch 011 | Loss: 0.1634 | Acc: 95.38% | Val Loss: 0.0293 | Val Acc: 99.48%
# Epoch 012 | Loss: 0.1490 | Acc: 95.71% | Val Loss: 0.0525 | Val Acc: 99.43%
# Epoch 013 | Loss: 0.1396 | Acc: 96.02% | Val Loss: 0.0323 | Val Acc: 99.29%
# Epoch 014 | Loss: 0.1310 | Acc: 96.27% | Val Loss: 0.0322 | Val Acc: 99.41%
# Epoch 015 | Loss: 0.1215 | Acc: 96.48% | Val Loss: 0.0220 | Val Acc: 99.63%
# Epoch 016 | Loss: 0.1151 | Acc: 96.74% | Val Loss: 0.0534 | Val Acc: 99.24%
# Epoch 017 | Loss: 0.1044 | Acc: 97.04% | Val Loss: 0.0363 | Val Acc: 99.35%
# Epoch 018 | Loss: 0.0978 | Acc: 97.14% | Val Loss: 0.0221 | Val Acc: 99.65%
#   LR: 0.001 → 0.0001
# Epoch 019 | Loss: 0.0956 | Acc: 97.26% | Val Loss: 0.0311 | Val Acc: 99.48%
# Epoch 020 | Loss: 0.0665 | Acc: 98.15% | Val Loss: 0.0139 | Val Acc: 99.75%
# Epoch 021 | Loss: 0.0588 | Acc: 98.32% | Val Loss: 0.0135 | Val Acc: 99.77%
# Epoch 022 | Loss: 0.0580 | Acc: 98.33% | Val Loss: 0.0136 | Val Acc: 99.79%
# Epoch 023 | Loss: 0.0582 | Acc: 98.33% | Val Loss: 0.0137 | Val Acc: 99.72%
# Epoch 024 | Loss: 0.0569 | Acc: 98.38% | Val Loss: 0.0127 | Val Acc: 99.79%
# Epoch 025 | Loss: 0.0542 | Acc: 98.47% | Val Loss: 0.0120 | Val Acc: 99.79%
# Epoch 026 | Loss: 0.0521 | Acc: 98.54% | Val Loss: 0.0121 | Val Acc: 99.77%
# Epoch 027 | Loss: 0.0509 | Acc: 98.62% | Val Loss: 0.0134 | Val Acc: 99.76%
# Epoch 028 | Loss: 0.0521 | Acc: 98.52% | Val Loss: 0.0132 | Val Acc: 99.73%
# Epoch 029 | Loss: 0.0473 | Acc: 98.66% | Val Loss: 0.0109 | Val Acc: 99.77%
# Treino concluído.
#
# Test Accuracy (run 0): 97.43%
#
# → geo2: média = 97.43% | std = 0.00%
#
# ============================================================
# EXPERIÊNCIA: geo2
# ============================================================
#
# --- Run 1/1 ---
# Epoch 000 | Loss: 3.5897 | Acc: 5.34% | Val Loss: 3.4947 | Val Acc: 5.35%
# Epoch 001 | Loss: 3.5000 | Acc: 5.23% | Val Loss: 3.4880 | Val Acc: 6.03%
# Epoch 002 | Loss: 3.4973 | Acc: 5.34% | Val Loss: 3.4906 | Val Acc: 5.35%
# Epoch 003 | Loss: 3.4942 | Acc: 5.47% | Val Loss: 3.4902 | Val Acc: 6.03%
# Epoch 004 | Loss: 3.4909 | Acc: 5.57% | Val Loss: 3.4883 | Val Acc: 5.28%
#   LR: 0.001 → 0.0001
# Epoch 005 | Loss: 3.4916 | Acc: 5.42% | Val Loss: 3.4896 | Val Acc: 5.35%
# Epoch 006 | Loss: 3.4890 | Acc: 5.47% | Val Loss: 3.4872 | Val Acc: 5.35%
# Epoch 007 | Loss: 3.4885 | Acc: 5.63% | Val Loss: 3.4869 | Val Acc: 5.35%
# Epoch 008 | Loss: 3.4878 | Acc: 5.48% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 009 | Loss: 3.4872 | Acc: 5.71% | Val Loss: 3.4868 | Val Acc: 5.35%
# Epoch 010 | Loss: 3.4877 | Acc: 5.66% | Val Loss: 3.4868 | Val Acc: 5.35%
#   LR: 0.0001 → 1e-05
# Epoch 011 | Loss: 3.4880 | Acc: 5.68% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 012 | Loss: 3.4869 | Acc: 5.64% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 013 | Loss: 3.4874 | Acc: 5.74% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 014 | Loss: 3.4882 | Acc: 5.73% | Val Loss: 3.4867 | Val Acc: 5.35%
#   LR: 1e-05 → 1.0000000000000002e-06
# Epoch 015 | Loss: 3.4873 | Acc: 5.59% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 016 | Loss: 3.4878 | Acc: 5.61% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 017 | Loss: 3.4880 | Acc: 5.63% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 018 | Loss: 3.4864 | Acc: 5.79% | Val Loss: 3.4867 | Val Acc: 5.35%
# Early stopping!
# Treino concluído.
#
# Test Accuracy (run 0): 5.70%
#
# → geo2: média = 5.70% | std = 0.00%
#
# ============================================================
# EXPERIÊNCIA: geo2
# ============================================================
#
# --- Run 1/1 ---
# Epoch 000 | Loss: 1.3667 | Acc: 55.88% | Val Loss: 0.6652 | Val Acc: 77.69%
# Epoch 001 | Loss: 0.5347 | Acc: 82.75% | Val Loss: 0.3392 | Val Acc: 88.50%
# Epoch 002 | Loss: 0.3075 | Acc: 90.90% | Val Loss: 0.2558 | Val Acc: 91.75%
# Epoch 003 | Loss: 0.2046 | Acc: 94.15% | Val Loss: 0.3831 | Val Acc: 90.49%
# Epoch 004 | Loss: 0.1642 | Acc: 95.42% | Val Loss: 0.2691 | Val Acc: 94.07%
# Epoch 005 | Loss: 0.1665 | Acc: 96.04% | Val Loss: 0.2107 | Val Acc: 95.97%
# Epoch 006 | Loss: 0.1336 | Acc: 96.89% | Val Loss: 0.2040 | Val Acc: 95.44%
# Epoch 007 | Loss: 0.1393 | Acc: 96.77% | Val Loss: 0.1714 | Val Acc: 96.21%
# Epoch 008 | Loss: 0.1028 | Acc: 97.80% | Val Loss: 0.1589 | Val Acc: 96.68%
# Epoch 009 | Loss: 0.1170 | Acc: 97.57% | Val Loss: 0.1902 | Val Acc: 96.96%
# Epoch 010 | Loss: 0.1098 | Acc: 97.98% | Val Loss: 0.1719 | Val Acc: 97.24%
# Epoch 011 | Loss: 0.1258 | Acc: 97.72% | Val Loss: 0.1595 | Val Acc: 97.35%
#   LR: 0.001 → 0.0001
# Epoch 012 | Loss: 0.0882 | Acc: 98.30% | Val Loss: 0.2544 | Val Acc: 95.56%
# Epoch 013 | Loss: 0.0292 | Acc: 99.27% | Val Loss: 0.0890 | Val Acc: 98.32%
# Epoch 014 | Loss: 0.0111 | Acc: 99.74% | Val Loss: 0.0798 | Val Acc: 98.67%
# Epoch 015 | Loss: 0.0057 | Acc: 99.88% | Val Loss: 0.0756 | Val Acc: 98.78%
# Epoch 016 | Loss: 0.0046 | Acc: 99.88% | Val Loss: 0.0740 | Val Acc: 98.80%
# Epoch 017 | Loss: 0.0054 | Acc: 99.88% | Val Loss: 0.0887 | Val Acc: 98.85%
# Epoch 018 | Loss: 0.0047 | Acc: 99.92% | Val Loss: 0.0870 | Val Acc: 98.81%
# Epoch 019 | Loss: 0.0033 | Acc: 99.91% | Val Loss: 0.0865 | Val Acc: 98.83%
#   LR: 0.0001 → 1e-05
# Epoch 020 | Loss: 0.0027 | Acc: 99.94% | Val Loss: 0.0855 | Val Acc: 98.90%
# Epoch 021 | Loss: 0.0024 | Acc: 99.96% | Val Loss: 0.0851 | Val Acc: 98.88%
# Epoch 022 | Loss: 0.0034 | Acc: 99.94% | Val Loss: 0.0856 | Val Acc: 98.94%
# Epoch 023 | Loss: 0.0026 | Acc: 99.96% | Val Loss: 0.0851 | Val Acc: 98.91%
#   LR: 1e-05 → 1.0000000000000002e-06
# Epoch 024 | Loss: 0.0011 | Acc: 99.96% | Val Loss: 0.0849 | Val Acc: 98.94%
# Epoch 025 | Loss: 0.0038 | Acc: 99.95% | Val Loss: 0.0848 | Val Acc: 98.97%
# Epoch 026 | Loss: 0.0016 | Acc: 99.98% | Val Loss: 0.0848 | Val Acc: 98.97%
# Early stopping!
# Treino concluído.
#
# Test Accuracy (run 0): 87.40%
#
# → geo2: média = 87.40% | std = 0.00%

# %% [markdown]
# ## Experience 3 - Augmentation de Cor

# %%
transform_color = v2.Compose([
    v2.Resize((IMG_SIZE_CONV, IMG_SIZE_CONV)),
    v2.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.3, hue=0.05),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True)
])

transform_color_vgg = v2.Compose([
    v2.Resize((IMG_SIZE_VGG, IMG_SIZE_VGG)),
    v2.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.3, hue=0.05),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

#results_color, mean_color, std_color = run_experiment(
#    name='aug_cor',
#    transform_train=transform_color,
#    transform_test=transform_base
#)

for model_name in ['conv_II', 'vgg16', 'vgg16_tl']:
    t_base = transform_base_vgg if model_name in ('vgg16', 'vgg16_tl') else transform_base
    t_train = transform_color_vgg if model_name in ('vgg16', 'vgg16_tl') else transform_color
    _, mean, std = run_experiment(
        name='color',
        transform_train=t_train,
        transform_test=t_base,
        model_name=model_name
    )
    all_results.append({'Modelo': model_name, 'Experiência': 'Cor', 'Média (%)': round(mean*100,2), 'Std (%)': round(std*100,3)})
# Out:
# ============================================================
# EXPERIÊNCIA: color
# ============================================================
#
# --- Run 1/1 ---
# Epoch 000 | Loss: 2.4930 | Acc: 30.34% | Val Loss: 1.6972 | Val Acc: 54.48%
# Epoch 001 | Loss: 1.5566 | Acc: 53.29% | Val Loss: 0.9880 | Val Acc: 73.96%
# Epoch 002 | Loss: 1.0483 | Acc: 68.67% | Val Loss: 0.5886 | Val Acc: 87.25%
# Epoch 003 | Loss: 0.7164 | Acc: 79.19% | Val Loss: 0.3048 | Val Acc: 92.98%
# Epoch 004 | Loss: 0.5276 | Acc: 84.97% | Val Loss: 0.1873 | Val Acc: 96.87%
# Epoch 005 | Loss: 0.4065 | Acc: 88.44% | Val Loss: 0.1474 | Val Acc: 97.88%
# Epoch 006 | Loss: 0.3298 | Acc: 90.50% | Val Loss: 0.1290 | Val Acc: 98.10%
# Epoch 007 | Loss: 0.2711 | Acc: 92.28% | Val Loss: 0.0695 | Val Acc: 98.80%
# Epoch 008 | Loss: 0.2301 | Acc: 93.38% | Val Loss: 0.0609 | Val Acc: 99.11%
# Epoch 009 | Loss: 0.2076 | Acc: 94.20% | Val Loss: 0.0584 | Val Acc: 99.18%
# Epoch 010 | Loss: 0.1869 | Acc: 94.73% | Val Loss: 0.0620 | Val Acc: 99.24%
# Epoch 011 | Loss: 0.1673 | Acc: 95.29% | Val Loss: 0.0448 | Val Acc: 99.04%
# Epoch 012 | Loss: 0.1558 | Acc: 95.48% | Val Loss: 0.0592 | Val Acc: 99.09%
# Epoch 013 | Loss: 0.1374 | Acc: 95.96% | Val Loss: 0.0420 | Val Acc: 99.05%
# Epoch 014 | Loss: 0.1330 | Acc: 96.21% | Val Loss: 0.0256 | Val Acc: 99.46%
# Epoch 015 | Loss: 0.1245 | Acc: 96.38% | Val Loss: 0.0333 | Val Acc: 99.45%
# Epoch 016 | Loss: 0.1152 | Acc: 96.50% | Val Loss: 0.0483 | Val Acc: 99.09%
# Epoch 017 | Loss: 0.1099 | Acc: 96.85% | Val Loss: 0.0313 | Val Acc: 99.46%
# Epoch 018 | Loss: 0.1027 | Acc: 97.07% | Val Loss: 0.0239 | Val Acc: 99.60%
# Epoch 019 | Loss: 0.0973 | Acc: 97.24% | Val Loss: 0.0219 | Val Acc: 99.59%
# Epoch 020 | Loss: 0.0952 | Acc: 97.21% | Val Loss: 0.0167 | Val Acc: 99.62%
# Epoch 021 | Loss: 0.0929 | Acc: 97.25% | Val Loss: 0.0170 | Val Acc: 99.76%
# Epoch 022 | Loss: 0.0797 | Acc: 97.62% | Val Loss: 0.0319 | Val Acc: 99.12%
# Epoch 023 | Loss: 0.0877 | Acc: 97.52% | Val Loss: 0.0221 | Val Acc: 99.52%
# Epoch 024 | Loss: 0.0829 | Acc: 97.57% | Val Loss: 0.0162 | Val Acc: 99.65%
# Epoch 025 | Loss: 0.0776 | Acc: 97.77% | Val Loss: 0.0131 | Val Acc: 99.65%
# Epoch 026 | Loss: 0.0732 | Acc: 97.87% | Val Loss: 0.0198 | Val Acc: 99.58%
# Epoch 027 | Loss: 0.0755 | Acc: 97.84% | Val Loss: 0.0170 | Val Acc: 99.60%
# Epoch 028 | Loss: 0.0695 | Acc: 97.99% | Val Loss: 0.0381 | Val Acc: 99.21%
#   LR: 0.001 → 0.0001
# Epoch 029 | Loss: 0.0743 | Acc: 97.93% | Val Loss: 0.0188 | Val Acc: 99.67%
# Treino concluído.
#
# Test Accuracy (run 0): 97.13%
#
# → color: média = 97.13% | std = 0.00%
#
# ============================================================
# EXPERIÊNCIA: color
# ============================================================
#
# --- Run 1/1 ---
# Epoch 000 | Loss: 3.7083 | Acc: 5.24% | Val Loss: 3.4906 | Val Acc: 5.35%
# Epoch 001 | Loss: 3.4999 | Acc: 5.36% | Val Loss: 3.4893 | Val Acc: 5.35%
# Epoch 002 | Loss: 3.4955 | Acc: 5.33% | Val Loss: 3.4908 | Val Acc: 5.35%
# Epoch 003 | Loss: 3.4926 | Acc: 5.42% | Val Loss: 3.4892 | Val Acc: 5.35%
# Epoch 004 | Loss: 3.4927 | Acc: 5.59% | Val Loss: 3.4896 | Val Acc: 4.68%
#   LR: 0.001 → 0.0001
# Epoch 005 | Loss: 3.4918 | Acc: 5.58% | Val Loss: 3.4910 | Val Acc: 6.03%
# Epoch 006 | Loss: 3.4893 | Acc: 5.59% | Val Loss: 3.4866 | Val Acc: 6.03%
# Epoch 007 | Loss: 3.4881 | Acc: 5.59% | Val Loss: 3.4868 | Val Acc: 5.35%
# Epoch 008 | Loss: 3.4884 | Acc: 5.60% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 009 | Loss: 3.4884 | Acc: 5.76% | Val Loss: 3.4866 | Val Acc: 5.35%
#   LR: 0.0001 → 1e-05
# Epoch 010 | Loss: 3.4884 | Acc: 5.48% | Val Loss: 3.4866 | Val Acc: 5.35%
# Epoch 011 | Loss: 3.4881 | Acc: 5.71% | Val Loss: 3.4866 | Val Acc: 5.35%
# Epoch 012 | Loss: 3.4873 | Acc: 5.57% | Val Loss: 3.4866 | Val Acc: 5.35%
# Epoch 013 | Loss: 3.4885 | Acc: 5.63% | Val Loss: 3.4866 | Val Acc: 5.35%
#   LR: 1e-05 → 1.0000000000000002e-06
# Epoch 014 | Loss: 3.4877 | Acc: 5.81% | Val Loss: 3.4866 | Val Acc: 5.35%
# Epoch 015 | Loss: 3.4870 | Acc: 5.73% | Val Loss: 3.4866 | Val Acc: 5.35%
# Epoch 016 | Loss: 3.4877 | Acc: 5.67% | Val Loss: 3.4866 | Val Acc: 5.35%
# Epoch 017 | Loss: 3.4874 | Acc: 5.61% | Val Loss: 3.4866 | Val Acc: 5.35%
#   LR: 1.0000000000000002e-06 → 1.0000000000000002e-07
# Epoch 018 | Loss: 3.4870 | Acc: 5.91% | Val Loss: 3.4866 | Val Acc: 5.35%
# Epoch 019 | Loss: 3.4869 | Acc: 5.79% | Val Loss: 3.4866 | Val Acc: 5.35%
# Early stopping!
# Treino concluído.
#
# Test Accuracy (run 0): 5.70%
#
# → color: média = 5.70% | std = 0.00%
#
# ============================================================
# EXPERIÊNCIA: color
# ============================================================
#
# --- Run 1/1 ---
# Epoch 000 | Loss: 1.1711 | Acc: 63.72% | Val Loss: 0.5099 | Val Acc: 83.29%
# Epoch 001 | Loss: 0.4036 | Acc: 87.62% | Val Loss: 0.2170 | Val Acc: 92.98%
# Epoch 002 | Loss: 0.2416 | Acc: 93.28% | Val Loss: 0.2568 | Val Acc: 92.83%
# Epoch 003 | Loss: 0.2241 | Acc: 94.62% | Val Loss: 0.3083 | Val Acc: 93.46%
# Epoch 004 | Loss: 0.1422 | Acc: 96.60% | Val Loss: 0.1887 | Val Acc: 95.08%
# Epoch 005 | Loss: 0.1466 | Acc: 96.71% | Val Loss: 0.1142 | Val Acc: 97.13%
# Epoch 006 | Loss: 0.1603 | Acc: 97.04% | Val Loss: 0.1052 | Val Acc: 97.50%
# Epoch 007 | Loss: 0.0966 | Acc: 97.98% | Val Loss: 0.2442 | Val Acc: 95.50%
# Epoch 008 | Loss: 0.1696 | Acc: 96.92% | Val Loss: 0.2123 | Val Acc: 96.65%
# Epoch 009 | Loss: 0.0910 | Acc: 98.30% | Val Loss: 0.1962 | Val Acc: 96.48%
#   LR: 0.001 → 0.0001
# Epoch 010 | Loss: 0.1376 | Acc: 97.76% | Val Loss: 0.1586 | Val Acc: 96.82%
# Epoch 011 | Loss: 0.0433 | Acc: 99.14% | Val Loss: 0.0711 | Val Acc: 98.37%
# Epoch 012 | Loss: 0.0105 | Acc: 99.73% | Val Loss: 0.0639 | Val Acc: 98.54%
# Epoch 013 | Loss: 0.0063 | Acc: 99.87% | Val Loss: 0.0646 | Val Acc: 98.67%
# Epoch 014 | Loss: 0.0045 | Acc: 99.91% | Val Loss: 0.0662 | Val Acc: 98.64%
# Epoch 015 | Loss: 0.0033 | Acc: 99.90% | Val Loss: 0.0665 | Val Acc: 98.74%
#   LR: 0.0001 → 1e-05
# Epoch 016 | Loss: 0.0027 | Acc: 99.94% | Val Loss: 0.0728 | Val Acc: 98.71%
# Epoch 017 | Loss: 0.0029 | Acc: 99.94% | Val Loss: 0.0716 | Val Acc: 98.70%
# Epoch 018 | Loss: 0.0031 | Acc: 99.94% | Val Loss: 0.0695 | Val Acc: 98.73%
# Epoch 019 | Loss: 0.0027 | Acc: 99.95% | Val Loss: 0.0698 | Val Acc: 98.77%
#   LR: 1e-05 → 1.0000000000000002e-06
# Epoch 020 | Loss: 0.0019 | Acc: 99.95% | Val Loss: 0.0709 | Val Acc: 98.68%
# Epoch 021 | Loss: 0.0009 | Acc: 99.97% | Val Loss: 0.0709 | Val Acc: 98.68%
# Epoch 022 | Loss: 0.0015 | Acc: 99.97% | Val Loss: 0.0708 | Val Acc: 98.68%
# Early stopping!
# Treino concluído.
#
# Test Accuracy (run 0): 86.51%
#
# → color: média = 86.51% | std = 0.00%

# %% [markdown]
# ## Experience 4 - Augmentation Combinada (geo + cor + erasing)

# %%
transform_combined = v2.Compose([
    v2.RandomRotation(15, interpolation=v2.InterpolationMode.BILINEAR),
    v2.Resize((IMG_SIZE_CONV, IMG_SIZE_CONV)),
    v2.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    v2.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.3, hue=0.05),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.RandomErasing(p=0.3, scale=(0.02, 0.1), value='random')  # simula oclusão
])

transform_combined_vgg = v2.Compose([
    v2.RandomRotation(15, interpolation=v2.InterpolationMode.BILINEAR),
    v2.Resize((IMG_SIZE_VGG, IMG_SIZE_VGG)),
    v2.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    v2.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.3, hue=0.05),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.RandomErasing(p=0.3, scale=(0.02, 0.1), value='random'),  # simula oclusão
    v2.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

#results_comb, mean_comb, std_comb = run_experiment(
#    name='aug_combinada',
#    transform_train=transform_combined,
#    transform_test=transform_base
#)

for model_name in ['conv_II', 'vgg16', 'vgg16_tl']:
    t_base = transform_base_vgg if model_name in ('vgg16', 'vgg16_tl') else transform_base
    t_train = transform_combined_vgg if model_name in ('vgg16', 'vgg16_tl') else transform_combined
    _, mean, std = run_experiment(
        name='combined',
        transform_train=t_train,
        transform_test=t_base,
        model_name=model_name
    )
    all_results.append({'Modelo': model_name, 'Experiência': 'Combinada', 'Média (%)': round(mean*100,2), 'Std (%)': round(std*100,3)})
# Out:
# ============================================================
# EXPERIÊNCIA: combined
# ============================================================
#
# --- Run 1/1 ---
# Epoch 000 | Loss: 2.4998 | Acc: 30.00% | Val Loss: 1.6782 | Val Acc: 55.75%
# Epoch 001 | Loss: 1.5315 | Acc: 53.73% | Val Loss: 0.8877 | Val Acc: 77.45%
# Epoch 002 | Loss: 1.0177 | Acc: 69.61% | Val Loss: 0.5598 | Val Acc: 86.36%
# Epoch 003 | Loss: 0.7100 | Acc: 78.73% | Val Loss: 0.3183 | Val Acc: 93.76%
# Epoch 004 | Loss: 0.5160 | Acc: 85.03% | Val Loss: 0.1961 | Val Acc: 96.97%
# Epoch 005 | Loss: 0.3894 | Acc: 89.07% | Val Loss: 0.1408 | Val Acc: 98.06%
# Epoch 006 | Loss: 0.3165 | Acc: 91.07% | Val Loss: 0.0860 | Val Acc: 98.49%
# Epoch 007 | Loss: 0.2568 | Acc: 92.64% | Val Loss: 0.0806 | Val Acc: 98.70%
# Epoch 008 | Loss: 0.2291 | Acc: 93.50% | Val Loss: 0.0654 | Val Acc: 99.12%
# Epoch 009 | Loss: 0.2004 | Acc: 94.28% | Val Loss: 0.0740 | Val Acc: 98.92%
# Epoch 010 | Loss: 0.1881 | Acc: 94.71% | Val Loss: 0.0520 | Val Acc: 99.28%
# Epoch 011 | Loss: 0.1561 | Acc: 95.61% | Val Loss: 0.0498 | Val Acc: 99.09%
# Epoch 012 | Loss: 0.1525 | Acc: 95.75% | Val Loss: 0.0296 | Val Acc: 99.41%
# Epoch 013 | Loss: 0.1330 | Acc: 96.23% | Val Loss: 0.0305 | Val Acc: 99.45%
# Epoch 014 | Loss: 0.1243 | Acc: 96.42% | Val Loss: 0.0268 | Val Acc: 99.59%
# Epoch 015 | Loss: 0.1107 | Acc: 96.88% | Val Loss: 0.0231 | Val Acc: 99.55%
# Epoch 016 | Loss: 0.1097 | Acc: 96.81% | Val Loss: 0.0260 | Val Acc: 99.55%
# Epoch 017 | Loss: 0.1029 | Acc: 97.06% | Val Loss: 0.0230 | Val Acc: 99.62%
# Epoch 018 | Loss: 0.1060 | Acc: 96.96% | Val Loss: 0.0183 | Val Acc: 99.58%
# Epoch 019 | Loss: 0.0946 | Acc: 97.25% | Val Loss: 0.0249 | Val Acc: 99.50%
# Epoch 020 | Loss: 0.0917 | Acc: 97.22% | Val Loss: 0.0235 | Val Acc: 99.43%
# Epoch 021 | Loss: 0.0854 | Acc: 97.51% | Val Loss: 0.0221 | Val Acc: 99.52%
#   LR: 0.001 → 0.0001
# Epoch 022 | Loss: 0.0852 | Acc: 97.57% | Val Loss: 0.0194 | Val Acc: 99.70%
# Epoch 023 | Loss: 0.0596 | Acc: 98.29% | Val Loss: 0.0121 | Val Acc: 99.73%
# Epoch 024 | Loss: 0.0525 | Acc: 98.46% | Val Loss: 0.0101 | Val Acc: 99.80%
# Epoch 025 | Loss: 0.0520 | Acc: 98.50% | Val Loss: 0.0102 | Val Acc: 99.82%
# Epoch 026 | Loss: 0.0473 | Acc: 98.71% | Val Loss: 0.0103 | Val Acc: 99.76%
# Epoch 027 | Loss: 0.0464 | Acc: 98.71% | Val Loss: 0.0088 | Val Acc: 99.83%
# Epoch 028 | Loss: 0.0447 | Acc: 98.79% | Val Loss: 0.0095 | Val Acc: 99.82%
# Epoch 029 | Loss: 0.0454 | Acc: 98.72% | Val Loss: 0.0094 | Val Acc: 99.80%
# Treino concluído.
#
# Test Accuracy (run 0): 97.59%
#
# → combined: média = 97.59% | std = 0.00%
#
# ============================================================
# EXPERIÊNCIA: combined
# ============================================================
#
# --- Run 1/1 ---
# Epoch 000 | Loss: 3.5985 | Acc: 5.40% | Val Loss: 3.4949 | Val Acc: 6.03%
# Epoch 001 | Loss: 3.5009 | Acc: 5.44% | Val Loss: 3.4891 | Val Acc: 5.35%
# Epoch 002 | Loss: 3.4958 | Acc: 5.51% | Val Loss: 3.4965 | Val Acc: 4.68%
# Epoch 003 | Loss: 3.4937 | Acc: 5.39% | Val Loss: 3.4894 | Val Acc: 5.35%
# Epoch 004 | Loss: 3.4913 | Acc: 5.40% | Val Loss: 3.4894 | Val Acc: 5.35%
# Epoch 005 | Loss: 3.4912 | Acc: 5.50% | Val Loss: 3.4882 | Val Acc: 5.63%
# Epoch 006 | Loss: 3.4915 | Acc: 5.45% | Val Loss: 3.4886 | Val Acc: 5.35%
# Epoch 007 | Loss: 3.4899 | Acc: 5.64% | Val Loss: 3.4873 | Val Acc: 6.03%
# Epoch 008 | Loss: 3.4906 | Acc: 5.40% | Val Loss: 3.4880 | Val Acc: 5.35%
# Epoch 009 | Loss: 3.4895 | Acc: 5.43% | Val Loss: 3.4871 | Val Acc: 6.03%
# Epoch 010 | Loss: 3.4884 | Acc: 5.54% | Val Loss: 3.4890 | Val Acc: 5.35%
#   LR: 0.001 → 0.0001
# Epoch 011 | Loss: 3.4883 | Acc: 5.60% | Val Loss: 3.4870 | Val Acc: 5.35%
# Epoch 012 | Loss: 3.4868 | Acc: 5.75% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 013 | Loss: 3.4876 | Acc: 5.66% | Val Loss: 3.4866 | Val Acc: 5.35%
# Epoch 014 | Loss: 3.4859 | Acc: 5.86% | Val Loss: 3.4866 | Val Acc: 5.35%
# Epoch 015 | Loss: 3.4867 | Acc: 5.60% | Val Loss: 3.4866 | Val Acc: 5.35%
#   LR: 0.0001 → 1e-05
# Epoch 016 | Loss: 3.4861 | Acc: 5.81% | Val Loss: 3.4866 | Val Acc: 5.35%
# Epoch 017 | Loss: 3.4869 | Acc: 5.61% | Val Loss: 3.4866 | Val Acc: 5.35%
# Epoch 018 | Loss: 3.4863 | Acc: 5.59% | Val Loss: 3.4866 | Val Acc: 5.35%
# Epoch 019 | Loss: 3.4855 | Acc: 5.73% | Val Loss: 3.4866 | Val Acc: 5.35%
#   LR: 1e-05 → 1.0000000000000002e-06
# Epoch 020 | Loss: 3.4860 | Acc: 5.64% | Val Loss: 3.4866 | Val Acc: 5.35%
# Epoch 021 | Loss: 3.4852 | Acc: 5.80% | Val Loss: 3.4866 | Val Acc: 5.35%
# Epoch 022 | Loss: 3.4856 | Acc: 5.67% | Val Loss: 3.4866 | Val Acc: 5.35%
# Epoch 023 | Loss: 3.4858 | Acc: 5.63% | Val Loss: 3.4866 | Val Acc: 5.35%
#   LR: 1.0000000000000002e-06 → 1.0000000000000002e-07
# Epoch 024 | Loss: 3.4863 | Acc: 5.64% | Val Loss: 3.4866 | Val Acc: 5.35%
# Epoch 025 | Loss: 3.4857 | Acc: 5.60% | Val Loss: 3.4866 | Val Acc: 5.35%
# Early stopping!
# Treino concluído.
#
# Test Accuracy (run 0): 5.70%
#
# → combined: média = 5.70% | std = 0.00%
#
# ============================================================
# EXPERIÊNCIA: combined
# ============================================================
#
# --- Run 1/1 ---
# Epoch 000 | Loss: 1.3046 | Acc: 58.36% | Val Loss: 0.5869 | Val Acc: 79.22%
# Epoch 001 | Loss: 0.4976 | Acc: 84.32% | Val Loss: 0.3382 | Val Acc: 89.46%
# Epoch 002 | Loss: 0.2925 | Acc: 91.61% | Val Loss: 0.3355 | Val Acc: 91.37%
# Epoch 003 | Loss: 0.2191 | Acc: 94.05% | Val Loss: 0.1651 | Val Acc: 95.35%
# Epoch 004 | Loss: 0.1986 | Acc: 95.31% | Val Loss: 0.1759 | Val Acc: 95.08%
# Epoch 005 | Loss: 0.1635 | Acc: 95.94% | Val Loss: 0.2361 | Val Acc: 95.54%
# Epoch 006 | Loss: 0.1396 | Acc: 96.96% | Val Loss: 0.1940 | Val Acc: 96.28%
#   LR: 0.001 → 0.0001
# Epoch 007 | Loss: 0.1636 | Acc: 97.02% | Val Loss: 0.2028 | Val Acc: 94.84%
# Epoch 008 | Loss: 0.0486 | Acc: 98.71% | Val Loss: 0.0936 | Val Acc: 97.79%
# Epoch 009 | Loss: 0.0163 | Acc: 99.54% | Val Loss: 0.0851 | Val Acc: 98.05%
# Epoch 010 | Loss: 0.0099 | Acc: 99.74% | Val Loss: 0.0758 | Val Acc: 98.27%
# Epoch 011 | Loss: 0.0056 | Acc: 99.84% | Val Loss: 0.0793 | Val Acc: 98.44%
# Epoch 012 | Loss: 0.0041 | Acc: 99.88% | Val Loss: 0.0921 | Val Acc: 98.42%
# Epoch 013 | Loss: 0.0044 | Acc: 99.88% | Val Loss: 0.0987 | Val Acc: 98.27%
#   LR: 0.0001 → 1e-05
# Epoch 014 | Loss: 0.0034 | Acc: 99.91% | Val Loss: 0.0887 | Val Acc: 98.51%
# Epoch 015 | Loss: 0.0023 | Acc: 99.96% | Val Loss: 0.0878 | Val Acc: 98.60%
# Epoch 016 | Loss: 0.0018 | Acc: 99.94% | Val Loss: 0.0871 | Val Acc: 98.64%
# Epoch 017 | Loss: 0.0024 | Acc: 99.95% | Val Loss: 0.0869 | Val Acc: 98.59%
#   LR: 1e-05 → 1.0000000000000002e-06
# Epoch 018 | Loss: 0.0020 | Acc: 99.96% | Val Loss: 0.0849 | Val Acc: 98.66%
# Epoch 019 | Loss: 0.0013 | Acc: 99.97% | Val Loss: 0.0850 | Val Acc: 98.66%
# Epoch 020 | Loss: 0.0012 | Acc: 99.98% | Val Loss: 0.0847 | Val Acc: 98.66%
# Early stopping!
# Treino concluído.
#
# Test Accuracy (run 0): 86.14%
#
# → combined: média = 86.14% | std = 0.00%

# %% [markdown]
# ## Experience 5 - Expansão Massiva do Dataset

# %%
transform_strong = v2.Compose([
    v2.RandomRotation(20, interpolation=v2.InterpolationMode.BILINEAR),
    v2.Resize((IMG_SIZE_CONV, IMG_SIZE_CONV)),
    v2.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    v2.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.3, hue=0.05),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.RandomErasing(p=0.3, scale=(0.02, 0.1), value='random')
])

transform_strong_vgg = v2.Compose([
    v2.RandomRotation(20, interpolation=v2.InterpolationMode.BILINEAR),
    v2.Resize((IMG_SIZE_VGG, IMG_SIZE_VGG)),
    v2.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    v2.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.3, hue=0.05),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.RandomErasing(p=0.3, scale=(0.02, 0.1), value='random'),
    v2.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Dataset expandido = original + versão augmentada
for model_name in ['conv_II', 'vgg16', 'vgg16_tl']:
    t_base   = transform_base_vgg  if model_name in ('vgg16', 'vgg16_tl') else transform_base
    t_strong = transform_strong_vgg if model_name in ('vgg16', 'vgg16_tl') else transform_strong

    full_original  = torchvision.datasets.ImageFolder(root=PATH_TRAIN, transform=t_base)
    full_augmented = torchvision.datasets.ImageFolder(root=PATH_TRAIN, transform=t_strong)
    expanded_dataset = torch.utils.data.ConcatDataset([full_original, full_augmented])

    train_size_exp = int(0.8 * len(expanded_dataset))
    val_size_exp   = len(expanded_dataset) - train_size_exp
    train_exp, val_exp = torch.utils.data.random_split(
        expanded_dataset, [train_size_exp, val_size_exp],
        generator=torch.Generator().manual_seed(42))

    test_set = torchvision.datasets.ImageFolder(root=PATH_TEST, transform=t_base)

    train_loader_exp = torch.utils.data.DataLoader(train_exp, batch_size=BATCH_SIZE, shuffle=True)
    val_loader_exp   = torch.utils.data.DataLoader(val_exp,   batch_size=BATCH_SIZE)
    test_loader      = torch.utils.data.DataLoader(test_set,  batch_size=BATCH_SIZE)

    results_exp = []
    for i in range(RUNS):
        print(f'\n--- Expansão Massiva [{model_name}] Run {i+1}/{RUNS} ---')
        if model_name == 'conv_II':
            model = conv_II(NUM_CLASSES).to(device)
        elif model_name == 'vgg16':
            model = torchvision.models.vgg16()
            n_inputs = model.classifier[0].in_features
            model.classifier = torch.nn.Sequential(
                torch.nn.Linear(n_inputs, 256),
                torch.nn.ReLU(),
                torch.nn.Dropout(0.5),
                torch.nn.Linear(256, NUM_CLASSES)
            )
            model.to(device)
        elif model_name == 'vgg16_tl':
            model = torchvision.models.vgg16(weights=torchvision.models.VGG16_Weights.IMAGENET1K_V1)
            for param in model.parameters():
                param.requires_grad = False
            for layer in [model.features[24], model.features[26]]:
                for param in layer.parameters():
                    param.requires_grad = True
            n_inputs = model.classifier[0].in_features
            model.classifier = torch.nn.Sequential(
                torch.nn.Linear(n_inputs, 256),
                torch.nn.ReLU(),
                torch.nn.Dropout(0.5),
                torch.nn.Linear(256, NUM_CLASSES)
            )
            model.to(device)

        loss_fn    = torch.nn.CrossEntropyLoss()
        optimizer  = torch.optim.Adam(model.parameters())
        scheduler  = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3)
        early_stop = EarlyStopping(patience=9)
        save_path  = f'{PATH_MODELS}/{model_name}_expansao_run{i}.pt'

        train(model, train_loader_exp, val_loader_exp, EPOCHS,
              loss_fn, optimizer, scheduler, early_stop, save_path)
        checkpoint = torch.load(save_path)
        model.load_state_dict(checkpoint['model'])
        acc = evaluate(model, test_loader)
        print(f'Test Accuracy: {acc*100:.2f}%')
        results_exp.append(acc)

    mean_exp = np.mean(results_exp)
    std_exp  = np.std(results_exp)
    print(f'\n→ Expansão Massiva [{model_name}]: média = {mean_exp*100:.2f}% | std = {std_exp*100:.2f}%')
    all_results.append({'Modelo': model_name, 'Experiência': 'Expansão Massiva', 'Média (%)': round(mean_exp*100,2), 'Std (%)': round(std_exp*100,3)})
# Out:
# --- Expansão Massiva [conv_II] Run 1/1 ---
# Epoch 000 | Loss: 2.4140 | Acc: 30.97% | Val Loss: 1.4809 | Val Acc: 58.82%
# Epoch 001 | Loss: 1.2991 | Acc: 60.92% | Val Loss: 0.7921 | Val Acc: 80.52%
# Epoch 002 | Loss: 0.8183 | Acc: 76.02% | Val Loss: 0.4391 | Val Acc: 91.24%
# Epoch 003 | Loss: 0.6067 | Acc: 82.26% | Val Loss: 0.2920 | Val Acc: 94.16%
# Epoch 004 | Loss: 0.5049 | Acc: 85.25% | Val Loss: 0.2606 | Val Acc: 94.77%
# Epoch 005 | Loss: 0.4349 | Acc: 87.42% | Val Loss: 0.2472 | Val Acc: 93.97%
# Epoch 006 | Loss: 0.3791 | Acc: 89.12% | Val Loss: 0.1777 | Val Acc: 95.58%
# Epoch 007 | Loss: 0.3522 | Acc: 89.85% | Val Loss: 0.2479 | Val Acc: 94.19%
# Epoch 008 | Loss: 0.3283 | Acc: 90.49% | Val Loss: 0.1581 | Val Acc: 95.93%
# Epoch 009 | Loss: 0.3072 | Acc: 90.95% | Val Loss: 0.1379 | Val Acc: 96.06%
# Epoch 010 | Loss: 0.2910 | Acc: 91.66% | Val Loss: 0.1288 | Val Acc: 96.64%
# Epoch 011 | Loss: 0.2780 | Acc: 92.01% | Val Loss: 0.1725 | Val Acc: 95.76%
# Epoch 012 | Loss: 0.2664 | Acc: 92.11% | Val Loss: 0.1146 | Val Acc: 96.98%
# Epoch 013 | Loss: 0.2538 | Acc: 92.52% | Val Loss: 0.1401 | Val Acc: 96.21%
# Epoch 014 | Loss: 0.2558 | Acc: 92.42% | Val Loss: 0.1357 | Val Acc: 96.39%
# Epoch 015 | Loss: 0.2415 | Acc: 92.89% | Val Loss: 0.1188 | Val Acc: 96.92%
# Epoch 016 | Loss: 0.2296 | Acc: 93.21% | Val Loss: 0.1146 | Val Acc: 96.97%
# Epoch 017 | Loss: 0.2254 | Acc: 93.37% | Val Loss: 0.1067 | Val Acc: 97.02%
# Epoch 018 | Loss: 0.2236 | Acc: 93.26% | Val Loss: 0.1079 | Val Acc: 97.13%
# Epoch 019 | Loss: 0.2255 | Acc: 93.43% | Val Loss: 0.1112 | Val Acc: 97.06%
# Epoch 020 | Loss: 0.2105 | Acc: 93.77% | Val Loss: 0.1141 | Val Acc: 96.85%
# Epoch 021 | Loss: 0.2108 | Acc: 93.81% | Val Loss: 0.1021 | Val Acc: 97.08%
# Epoch 022 | Loss: 0.2065 | Acc: 93.97% | Val Loss: 0.0976 | Val Acc: 97.38%
# Epoch 023 | Loss: 0.2017 | Acc: 94.08% | Val Loss: 0.1159 | Val Acc: 96.98%
# Epoch 024 | Loss: 0.1948 | Acc: 94.29% | Val Loss: 0.0916 | Val Acc: 97.45%
# Epoch 025 | Loss: 0.1958 | Acc: 94.17% | Val Loss: 0.1323 | Val Acc: 96.36%
# Epoch 026 | Loss: 0.1949 | Acc: 94.23% | Val Loss: 0.0865 | Val Acc: 97.72%
# Epoch 027 | Loss: 0.1877 | Acc: 94.46% | Val Loss: 0.0864 | Val Acc: 97.63%
# Epoch 028 | Loss: 0.1843 | Acc: 94.65% | Val Loss: 0.0819 | Val Acc: 97.72%
# Epoch 029 | Loss: 0.1878 | Acc: 94.48% | Val Loss: 0.0972 | Val Acc: 97.21%
# Treino concluído.
#
# Test Accuracy: 98.57%
#
# → Expansão Massiva [conv_II]: média = 98.57% | std = 0.00%
#
# --- Expansão Massiva [vgg16] Run 1/1 ---
# Epoch 000 | Loss: 3.5322 | Acc: 5.44% | Val Loss: 3.4963 | Val Acc: 5.45%
# Epoch 001 | Loss: 3.4948 | Acc: 5.50% | Val Loss: 3.4927 | Val Acc: 5.45%
# Epoch 002 | Loss: 3.4915 | Acc: 5.58% | Val Loss: 3.4923 | Val Acc: 5.45%
# Epoch 003 | Loss: 3.4904 | Acc: 5.52% | Val Loss: 3.4905 | Val Acc: 5.29%
# Epoch 004 | Loss: 3.4882 | Acc: 5.66% | Val Loss: 3.4918 | Val Acc: 5.64%
# Epoch 005 | Loss: 3.4876 | Acc: 5.58% | Val Loss: 3.4905 | Val Acc: 5.64%
# Epoch 006 | Loss: 3.4864 | Acc: 5.59% | Val Loss: 3.4913 | Val Acc: 5.78%
#   LR: 0.001 → 0.0001
# Epoch 007 | Loss: 3.4864 | Acc: 5.64% | Val Loss: 3.4907 | Val Acc: 5.78%
# Epoch 008 | Loss: 3.4855 | Acc: 5.61% | Val Loss: 3.4901 | Val Acc: 5.64%
# Epoch 009 | Loss: 3.4852 | Acc: 5.59% | Val Loss: 3.4901 | Val Acc: 5.64%
# Epoch 010 | Loss: 3.4846 | Acc: 5.73% | Val Loss: 3.4900 | Val Acc: 5.64%
# Epoch 011 | Loss: 3.4842 | Acc: 5.58% | Val Loss: 3.4900 | Val Acc: 5.78%
# Epoch 012 | Loss: 3.4846 | Acc: 5.61% | Val Loss: 3.4900 | Val Acc: 5.64%
#   LR: 0.0001 → 1e-05
# Epoch 013 | Loss: 3.4847 | Acc: 5.65% | Val Loss: 3.4901 | Val Acc: 5.64%
# Epoch 014 | Loss: 3.4845 | Acc: 5.61% | Val Loss: 3.4901 | Val Acc: 5.64%
# Epoch 015 | Loss: 3.4845 | Acc: 5.62% | Val Loss: 3.4901 | Val Acc: 5.64%
# Epoch 016 | Loss: 3.4846 | Acc: 5.63% | Val Loss: 3.4901 | Val Acc: 5.64%
#   LR: 1e-05 → 1.0000000000000002e-06
# Epoch 017 | Loss: 3.4845 | Acc: 5.64% | Val Loss: 3.4901 | Val Acc: 5.64%
# Epoch 018 | Loss: 3.4844 | Acc: 5.68% | Val Loss: 3.4901 | Val Acc: 5.64%
# Epoch 019 | Loss: 3.4844 | Acc: 5.85% | Val Loss: 3.4901 | Val Acc: 5.64%
# Epoch 020 | Loss: 3.4843 | Acc: 5.65% | Val Loss: 3.4901 | Val Acc: 5.64%
# Early stopping!
# Treino concluído.
#
# Test Accuracy: 5.70%
#
# → Expansão Massiva [vgg16]: média = 5.70% | std = 0.00%
#
# --- Expansão Massiva [vgg16_tl] Run 1/1 ---
# Epoch 000 | Loss: 1.4915 | Acc: 52.88% | Val Loss: 0.9664 | Val Acc: 68.63%
# Epoch 001 | Loss: 0.9006 | Acc: 72.00% | Val Loss: 0.6847 | Val Acc: 78.22%
# Epoch 002 | Loss: 0.7274 | Acc: 77.97% | Val Loss: 0.6250 | Val Acc: 80.56%
# Epoch 003 | Loss: 0.6582 | Acc: 80.47% | Val Loss: 0.5820 | Val Acc: 81.17%
# Epoch 004 | Loss: 0.6104 | Acc: 82.09% | Val Loss: 0.5949 | Val Acc: 82.18%
# Epoch 005 | Loss: 0.5894 | Acc: 82.85% | Val Loss: 0.5052 | Val Acc: 85.05%
# Epoch 006 | Loss: 0.5621 | Acc: 83.85% | Val Loss: 0.5057 | Val Acc: 84.65%
# Epoch 007 | Loss: 0.5575 | Acc: 84.08% | Val Loss: 0.4797 | Val Acc: 86.02%
# Epoch 008 | Loss: 0.5419 | Acc: 84.68% | Val Loss: 0.4857 | Val Acc: 85.09%
# Epoch 009 | Loss: 0.5363 | Acc: 84.69% | Val Loss: 0.4760 | Val Acc: 85.78%
# Epoch 010 | Loss: 0.5178 | Acc: 85.29% | Val Loss: 0.5146 | Val Acc: 85.31%
# Epoch 011 | Loss: 0.5326 | Acc: 85.13% | Val Loss: 0.4797 | Val Acc: 85.86%
# Epoch 012 | Loss: 0.5470 | Acc: 85.03% | Val Loss: 0.5425 | Val Acc: 86.01%
#   LR: 0.001 → 0.0001
# Epoch 013 | Loss: 0.5221 | Acc: 85.40% | Val Loss: 0.4908 | Val Acc: 86.49%
# Epoch 014 | Loss: 0.4023 | Acc: 88.37% | Val Loss: 0.3673 | Val Acc: 89.29%
# Epoch 015 | Loss: 0.3634 | Acc: 89.32% | Val Loss: 0.3381 | Val Acc: 89.87%
# Epoch 016 | Loss: 0.3368 | Acc: 89.95% | Val Loss: 0.3255 | Val Acc: 90.30%
# Epoch 017 | Loss: 0.3240 | Acc: 90.43% | Val Loss: 0.3190 | Val Acc: 90.37%
# Epoch 018 | Loss: 0.3171 | Acc: 90.35% | Val Loss: 0.3193 | Val Acc: 90.47%
# Epoch 019 | Loss: 0.3135 | Acc: 90.56% | Val Loss: 0.3146 | Val Acc: 90.61%
# Epoch 020 | Loss: 0.3056 | Acc: 90.85% | Val Loss: 0.3118 | Val Acc: 90.54%
# Epoch 021 | Loss: 0.3048 | Acc: 90.74% | Val Loss: 0.3106 | Val Acc: 90.77%
# Epoch 022 | Loss: 0.2953 | Acc: 91.00% | Val Loss: 0.2991 | Val Acc: 91.00%
# Epoch 023 | Loss: 0.2963 | Acc: 90.95% | Val Loss: 0.2851 | Val Acc: 90.98%
# Epoch 024 | Loss: 0.2952 | Acc: 90.99% | Val Loss: 0.3024 | Val Acc: 90.99%
# Epoch 025 | Loss: 0.2856 | Acc: 91.23% | Val Loss: 0.2804 | Val Acc: 91.41%
# Epoch 026 | Loss: 0.2850 | Acc: 91.23% | Val Loss: 0.2838 | Val Acc: 91.43%
# Epoch 027 | Loss: 0.2804 | Acc: 91.37% | Val Loss: 0.2949 | Val Acc: 91.46%
# Epoch 028 | Loss: 0.2827 | Acc: 91.47% | Val Loss: 0.2952 | Val Acc: 91.11%
# Epoch 029 | Loss: 0.2863 | Acc: 91.29% | Val Loss: 0.2798 | Val Acc: 91.40%
# Treino concluído.
#
# Test Accuracy: 89.84%
#
# → Expansão Massiva [vgg16_tl]: média = 89.84% | std = 0.00%

# %% [markdown]
# ## Experience 6 - Augmentation com MixUp e CutMix

# %%
def train_mixup(model, train_loader, val_loader, epochs, loss_fn, optimizer,
                scheduler, early_stopper, save_path):
    
    mixup = v2.MixUp(num_classes=NUM_CLASSES)
    history = {'loss': [], 'accuracy': [], 'val_loss': [], 'val_acc': []}
    best_val_loss = np.inf

    for epoch in range(epochs):
        model.train()
        running_loss, correct = 0.0, 0
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            
            # única diferença: aplica mixup ao batch antes do forward pass
            inputs, targets_mix = mixup(inputs, targets)
            
            outputs = model(inputs)
            loss = loss_fn(outputs, targets_mix)   # targets_mix são soft labels
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item() * inputs.size(0)
            # accuracy com labels originais (duras), não as soft
            _, predicted = torch.max(outputs, 1)
            hard = torch.argmax(targets_mix, dim=1)
            correct += (predicted == hard).sum()

        # validação igual ao train() original — sem mixup
        model.eval()
        val_loss, v_correct = 0.0, 0
        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                val_loss += loss_fn(outputs,
                    torch.nn.functional.one_hot(targets, NUM_CLASSES).float()
                ).item() * targets.size(0)
                v_correct += (preds == targets).sum()

        # resto igual ao train() original
        old_lr = optimizer.param_groups[0]['lr']
        scheduler.step(val_loss)
        new_lr = optimizer.param_groups[0]['lr']
        if old_lr != new_lr:
            print(f'  LR: {old_lr} → {new_lr}')

        epoch_loss = running_loss / len(train_loader.dataset)
        acc        = 100 * correct / len(train_loader.dataset)
        v_acc      = 100 * v_correct / len(val_loader.dataset)
        val_loss  /= len(val_loader.dataset)

        history['loss'].append(epoch_loss)
        history['accuracy'].append(acc.cpu().numpy())
        history['val_loss'].append(val_loss)
        history['val_acc'].append(v_acc.cpu().numpy())

        print(f'Epoch {epoch:03d} | Loss: {epoch_loss:.4f} | Acc: {acc:.2f}% '
              f'| Val Loss: {val_loss:.4f} | Val Acc: {v_acc:.2f}%')

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save({'epoch': epoch, 'model': model.state_dict(),
                        'optimizer': optimizer.state_dict(),
                        'scheduler': scheduler.state_dict()}, save_path)

        if early_stopper(val_loss):
            print('Early stopping!')
            break

    print('Treino concluído.\n')
    return history

# %%
def run_experiment_mix(name, transform_train, transform_test, model_name='conv_II', n_runs=RUNS):
    print(f'\n{"="*60}')
    print(f'EXPERIÊNCIA: {name}')
    print(f'{"="*60}')

    # Divisão treino/validação (80/20) a partir do train_images
    full_train = torchvision.datasets.ImageFolder(
        root=PATH_TRAIN, transform=transform_train)
    
    val_size   = int(0.2 * len(full_train))
    train_size = len(full_train) - val_size
    train_set, val_set = torch.utils.data.random_split(
        full_train, [train_size, val_size],
        generator=torch.Generator().manual_seed(42))

    val_set.dataset.transform = transform_base_vgg if model_name in ('vgg16','vgg16_tl') else transform_base

    test_set = torchvision.datasets.ImageFolder(
        root=PATH_TEST, transform=transform_test)

    train_loader = torch.utils.data.DataLoader(
        train_set, batch_size=BATCH_SIZE, shuffle=True)
    val_loader   = torch.utils.data.DataLoader(
        val_set,   batch_size=BATCH_SIZE)
    test_loader  = torch.utils.data.DataLoader(
        test_set,  batch_size=BATCH_SIZE)

    results = []
    for i in range(n_runs):
        print(f'\n--- Run {i+1}/{n_runs} ---')

        if model_name == 'conv_II':
            model = conv_II(NUM_CLASSES).to(device)
        elif model_name == 'vgg16':
            model = torchvision.models.vgg16()
            n_inputs = model.classifier[0].in_features
            model.classifier = torch.nn.Sequential(
                torch.nn.Linear(n_inputs, 256),
                torch.nn.ReLU(),
                torch.nn.Dropout(0.5),
                torch.nn.Linear(256, NUM_CLASSES)
            )
            model.to(device)
        elif model_name == 'vgg16_tl':
            model = torchvision.models.vgg16(weights=torchvision.models.VGG16_Weights.IMAGENET1K_V1)
            for param in model.parameters():
                param.requires_grad = False
            for layer in [model.features[24], model.features[26]]:
                for param in layer.parameters():
                    param.requires_grad = True
            n_inputs = model.classifier[0].in_features
            model.classifier = torch.nn.Sequential(
                torch.nn.Linear(n_inputs, 256),
                torch.nn.ReLU(),
                torch.nn.Dropout(0.5),
                torch.nn.Linear(256, NUM_CLASSES)
            )
            model.to(device)
        
        loss_fn    = torch.nn.CrossEntropyLoss()
        optimizer  = torch.optim.Adam(model.parameters())
        scheduler  = torch.optim.lr_scheduler.ReduceLROnPlateau(
                         optimizer, mode='min', factor=0.1, patience=3)
        early_stop = EarlyStopping(patience=9)
        save_path  = f'{PATH_MODELS}/{name}_run{i}.pt'

        history = train_mixup(model, train_loader, val_loader, EPOCHS,
                        loss_fn, optimizer, scheduler, early_stop, save_path)

        # Recarregar melhor checkpoint
        checkpoint = torch.load(save_path)
        model.load_state_dict(checkpoint['model'])
        acc = evaluate(model, test_loader)
        print(f'Test Accuracy (run {i}): {acc*100:.2f}%')
        results.append(acc)

    mean_acc = np.mean(results)
    std_acc  = np.std(results)
    print(f'\n→ {name}: média = {mean_acc*100:.2f}% | std = {std_acc*100:.2f}%')
    return results, mean_acc, std_acc

# %%
transform_mix = v2.Compose([
    v2.Resize((IMG_SIZE_CONV, IMG_SIZE_CONV)),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
])

transform_mix_vgg = v2.Compose([
    v2.Resize((IMG_SIZE_VGG, IMG_SIZE_VGG)),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

#results_mix, mean_mix, std_mix = run_experiment_mix(
#    name='aug_mix',
#    transform_train=transform_mix,
#    transform_test=transform_base
#)

for model_name in ['conv_II', 'vgg16', 'vgg16_tl']:
    t_base = transform_base_vgg if model_name in ('vgg16', 'vgg16_tl') else transform_base
    t_train = transform_mix_vgg if model_name in ('vgg16', 'vgg16_tl') else transform_mix
    _, mean, std = run_experiment(
        name='mix',
        transform_train=t_train,
        transform_test=t_base,
        model_name=model_name
    )
    all_results.append({'Modelo': model_name, 'Experiência': 'CutMix e MixUp', 'Média (%)': round(mean*100,2), 'Std (%)': round(std*100,3)})
# Out:
# ============================================================
# EXPERIÊNCIA: mix
# ============================================================
#
# --- Run 1/1 ---
# Epoch 000 | Loss: 2.5495 | Acc: 29.42% | Val Loss: 1.6876 | Val Acc: 52.16%
# Epoch 001 | Loss: 1.5426 | Acc: 53.56% | Val Loss: 0.8936 | Val Acc: 75.48%
# Epoch 002 | Loss: 1.0305 | Acc: 69.27% | Val Loss: 0.5411 | Val Acc: 87.96%
# Epoch 003 | Loss: 0.7126 | Acc: 79.08% | Val Loss: 0.2928 | Val Acc: 93.85%
# Epoch 004 | Loss: 0.5175 | Acc: 84.89% | Val Loss: 0.1919 | Val Acc: 96.89%
# Epoch 005 | Loss: 0.3958 | Acc: 88.74% | Val Loss: 0.1432 | Val Acc: 97.96%
# Epoch 006 | Loss: 0.3112 | Acc: 91.43% | Val Loss: 0.0984 | Val Acc: 98.56%
# Epoch 007 | Loss: 0.2625 | Acc: 92.80% | Val Loss: 0.0640 | Val Acc: 98.54%
# Epoch 008 | Loss: 0.2240 | Acc: 93.74% | Val Loss: 0.0638 | Val Acc: 98.95%
# Epoch 009 | Loss: 0.1943 | Acc: 94.53% | Val Loss: 0.0495 | Val Acc: 99.32%
# Epoch 010 | Loss: 0.1766 | Acc: 95.17% | Val Loss: 0.0509 | Val Acc: 99.22%
# Epoch 011 | Loss: 0.1598 | Acc: 95.36% | Val Loss: 0.0457 | Val Acc: 99.00%
# Epoch 012 | Loss: 0.1415 | Acc: 96.20% | Val Loss: 0.0380 | Val Acc: 99.48%
# Epoch 013 | Loss: 0.1342 | Acc: 96.24% | Val Loss: 0.0323 | Val Acc: 99.38%
# Epoch 014 | Loss: 0.1213 | Acc: 96.53% | Val Loss: 0.0354 | Val Acc: 99.36%
# Epoch 015 | Loss: 0.1131 | Acc: 96.86% | Val Loss: 0.0300 | Val Acc: 99.42%
# Epoch 016 | Loss: 0.1106 | Acc: 96.94% | Val Loss: 0.0345 | Val Acc: 99.31%
# Epoch 017 | Loss: 0.1015 | Acc: 97.09% | Val Loss: 0.0243 | Val Acc: 99.55%
# Epoch 018 | Loss: 0.0992 | Acc: 97.10% | Val Loss: 0.0190 | Val Acc: 99.59%
# Epoch 019 | Loss: 0.0891 | Acc: 97.49% | Val Loss: 0.0187 | Val Acc: 99.56%
# Epoch 020 | Loss: 0.0814 | Acc: 97.69% | Val Loss: 0.0179 | Val Acc: 99.60%
# Epoch 021 | Loss: 0.0881 | Acc: 97.37% | Val Loss: 0.0227 | Val Acc: 99.55%
# Epoch 022 | Loss: 0.0785 | Acc: 97.73% | Val Loss: 0.0253 | Val Acc: 99.46%
# Epoch 023 | Loss: 0.0789 | Acc: 97.72% | Val Loss: 0.0228 | Val Acc: 99.50%
#   LR: 0.001 → 0.0001
# Epoch 024 | Loss: 0.0727 | Acc: 97.94% | Val Loss: 0.0248 | Val Acc: 99.41%
# Epoch 025 | Loss: 0.0521 | Acc: 98.53% | Val Loss: 0.0111 | Val Acc: 99.73%
# Epoch 026 | Loss: 0.0479 | Acc: 98.57% | Val Loss: 0.0109 | Val Acc: 99.76%
# Epoch 027 | Loss: 0.0419 | Acc: 98.85% | Val Loss: 0.0104 | Val Acc: 99.75%
# Epoch 028 | Loss: 0.0453 | Acc: 98.76% | Val Loss: 0.0102 | Val Acc: 99.77%
# Epoch 029 | Loss: 0.0427 | Acc: 98.84% | Val Loss: 0.0097 | Val Acc: 99.83%
# Treino concluído.
#
# Test Accuracy (run 0): 97.76%
#
# → mix: média = 97.76% | std = 0.00%
#
# ============================================================
# EXPERIÊNCIA: mix
# ============================================================
#
# --- Run 1/1 ---
# Epoch 000 | Loss: 3.9567 | Acc: 5.50% | Val Loss: 3.4892 | Val Acc: 6.03%
# Epoch 001 | Loss: 3.4984 | Acc: 5.51% | Val Loss: 3.4881 | Val Acc: 5.63%
# Epoch 002 | Loss: 3.4956 | Acc: 5.37% | Val Loss: 3.4895 | Val Acc: 5.35%
# Epoch 003 | Loss: 3.4942 | Acc: 5.77% | Val Loss: 3.4885 | Val Acc: 5.63%
# Epoch 004 | Loss: 3.4923 | Acc: 5.56% | Val Loss: 3.4886 | Val Acc: 6.03%
#   LR: 0.001 → 0.0001
# Epoch 005 | Loss: 3.4911 | Acc: 5.72% | Val Loss: 3.4891 | Val Acc: 6.03%
# Epoch 006 | Loss: 3.4894 | Acc: 5.70% | Val Loss: 3.4876 | Val Acc: 5.35%
# Epoch 007 | Loss: 3.4889 | Acc: 5.73% | Val Loss: 3.4872 | Val Acc: 5.35%
# Epoch 008 | Loss: 3.4880 | Acc: 5.66% | Val Loss: 3.4869 | Val Acc: 5.35%
# Epoch 009 | Loss: 3.4879 | Acc: 5.79% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 010 | Loss: 3.4882 | Acc: 5.59% | Val Loss: 3.4869 | Val Acc: 5.35%
# Epoch 011 | Loss: 3.4876 | Acc: 5.61% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 012 | Loss: 3.4881 | Acc: 5.83% | Val Loss: 3.4867 | Val Acc: 5.35%
#   LR: 0.0001 → 1e-05
# Epoch 013 | Loss: 3.4877 | Acc: 5.71% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 014 | Loss: 3.4885 | Acc: 5.76% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 015 | Loss: 3.4866 | Acc: 5.59% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 016 | Loss: 3.4879 | Acc: 5.64% | Val Loss: 3.4867 | Val Acc: 5.35%
#   LR: 1e-05 → 1.0000000000000002e-06
# Epoch 017 | Loss: 3.4870 | Acc: 5.68% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 018 | Loss: 3.4872 | Acc: 5.76% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 019 | Loss: 3.4870 | Acc: 5.69% | Val Loss: 3.4867 | Val Acc: 5.35%
# Epoch 020 | Loss: 3.4873 | Acc: 5.59% | Val Loss: 3.4867 | Val Acc: 5.35%
#   LR: 1.0000000000000002e-06 → 1.0000000000000002e-07
# Epoch 021 | Loss: 3.4879 | Acc: 5.52% | Val Loss: 3.4867 | Val Acc: 5.35%
# Early stopping!
# Treino concluído.
#
# Test Accuracy (run 0): 5.70%
#
# → mix: média = 5.70% | std = 0.00%
#
# ============================================================
# EXPERIÊNCIA: mix
# ============================================================
#
# --- Run 1/1 ---
# Epoch 000 | Loss: 1.2498 | Acc: 59.96% | Val Loss: 0.5222 | Val Acc: 82.84%
# Epoch 001 | Loss: 0.4444 | Acc: 85.59% | Val Loss: 0.2702 | Val Acc: 91.36%
# Epoch 002 | Loss: 0.3000 | Acc: 91.36% | Val Loss: 0.3002 | Val Acc: 90.92%
# Epoch 003 | Loss: 0.2147 | Acc: 94.50% | Val Loss: 0.1552 | Val Acc: 95.30%
# Epoch 004 | Loss: 0.1775 | Acc: 95.56% | Val Loss: 0.2247 | Val Acc: 94.36%
# Epoch 005 | Loss: 0.1340 | Acc: 96.79% | Val Loss: 0.1515 | Val Acc: 96.36%
# Epoch 006 | Loss: 0.1540 | Acc: 96.60% | Val Loss: 0.3712 | Val Acc: 95.54%
# Epoch 007 | Loss: 0.1311 | Acc: 97.26% | Val Loss: 0.1789 | Val Acc: 96.41%
# Epoch 008 | Loss: 0.1975 | Acc: 96.58% | Val Loss: 0.1325 | Val Acc: 97.10%
# Epoch 009 | Loss: 0.1132 | Acc: 97.98% | Val Loss: 0.2196 | Val Acc: 96.02%
# Epoch 010 | Loss: 0.1130 | Acc: 97.92% | Val Loss: 0.1074 | Val Acc: 98.02%
# Epoch 011 | Loss: 0.1318 | Acc: 97.68% | Val Loss: 0.1381 | Val Acc: 97.28%
# Epoch 012 | Loss: 0.0957 | Acc: 98.33% | Val Loss: 0.1515 | Val Acc: 97.21%
# Epoch 013 | Loss: 0.1994 | Acc: 97.10% | Val Loss: 0.1883 | Val Acc: 95.98%
#   LR: 0.001 → 0.0001
# Epoch 014 | Loss: 0.0981 | Acc: 98.40% | Val Loss: 0.5276 | Val Acc: 94.54%
# Epoch 015 | Loss: 0.0469 | Acc: 99.05% | Val Loss: 0.1098 | Val Acc: 98.22%
# Epoch 016 | Loss: 0.0145 | Acc: 99.67% | Val Loss: 0.1073 | Val Acc: 98.44%
# Epoch 017 | Loss: 0.0075 | Acc: 99.83% | Val Loss: 0.1004 | Val Acc: 98.47%
# Epoch 018 | Loss: 0.0054 | Acc: 99.89% | Val Loss: 0.1035 | Val Acc: 98.43%
# Epoch 019 | Loss: 0.0039 | Acc: 99.91% | Val Loss: 0.1051 | Val Acc: 98.39%
# Epoch 020 | Loss: 0.0053 | Acc: 99.91% | Val Loss: 0.1095 | Val Acc: 98.50%
#   LR: 0.0001 → 1e-05
# Epoch 021 | Loss: 0.0025 | Acc: 99.93% | Val Loss: 0.1142 | Val Acc: 98.54%
# Epoch 022 | Loss: 0.0043 | Acc: 99.94% | Val Loss: 0.1118 | Val Acc: 98.53%
# Epoch 023 | Loss: 0.0036 | Acc: 99.94% | Val Loss: 0.1104 | Val Acc: 98.56%
# Epoch 024 | Loss: 0.0016 | Acc: 99.96% | Val Loss: 0.1088 | Val Acc: 98.57%
#   LR: 1e-05 → 1.0000000000000002e-06
# Epoch 025 | Loss: 0.0020 | Acc: 99.96% | Val Loss: 0.1097 | Val Acc: 98.57%
# Epoch 026 | Loss: 0.0037 | Acc: 99.95% | Val Loss: 0.1096 | Val Acc: 98.57%
# Epoch 027 | Loss: 0.0014 | Acc: 99.95% | Val Loss: 0.1097 | Val Acc: 98.59%
# Early stopping!
# Treino concluído.
#
# Test Accuracy (run 0): 86.61%
#
# → mix: média = 86.61% | std = 0.00%

# %% [markdown]
# ## Tabela Comparativa de Resultados

# %%
summary = pd.DataFrame(all_results)

# %%
summary
# Out:
#       Modelo       Experiência  Média (%)  Std (%)
# 0    conv_II          Baseline      97.28      0.0
# 1      vgg16          Baseline       5.70      0.0
# 2   vgg16_tl          Baseline      86.66      0.0
# 3    conv_II        Geométrica      96.60      0.0
# 4      vgg16        Geométrica       5.70      0.0
# 5   vgg16_tl        Geométrica      88.07      0.0
# 6    conv_II      Geométrica 2      97.43      0.0
# 7      vgg16      Geométrica 2       5.70      0.0
# 8   vgg16_tl      Geométrica 2      87.40      0.0
# 9    conv_II               Cor      97.13      0.0
# 10     vgg16               Cor       5.70      0.0
# 11  vgg16_tl               Cor      86.51      0.0
# 12   conv_II         Combinada      97.59      0.0
# 13     vgg16         Combinada       5.70      0.0
# 14  vgg16_tl         Combinada      86.14      0.0
# 15   conv_II    CutMix e MixUp      97.76      0.0
# 16     vgg16    CutMix e MixUp       5.70      0.0
# 17  vgg16_tl    CutMix e MixUp      86.61      0.0
# 18   conv_II  Expansão Massiva      98.57      0.0
# 19     vgg16  Expansão Massiva       5.70      0.0
# 20  vgg16_tl  Expansão Massiva      89.84      0.0

# %%
print(summary.pivot(index='Experiência', columns='Modelo', values='Média (%)').to_string())

pivot = summary.pivot(index='Experiência', columns='Modelo', values='Média (%)')
pivot.plot(kind='bar', figsize=(12, 5), capsize=4)
plt.ylabel('Accuracy no teste (%)')
plt.title('Comparação de modelos × augmentação — GTSRB')
plt.xticks(rotation=10)
plt.legend(title='Modelo')
plt.tight_layout()
plt.show()
# Out:
# Modelo            conv_II  vgg16  vgg16_tl
# Experiência
# Baseline            97.28    5.7     86.66
# Combinada           97.59    5.7     86.14
# Cor                 97.13    5.7     86.51
# CutMix e MixUp      97.76    5.7     86.61
# Expansão Massiva    98.57    5.7     89.84
# Geométrica          96.60    5.7     88.07
# Geométrica 2        97.43    5.7     87.40

# %% [markdown]
# ## Análise de Resultados

# %%
def load_model(model_name, exp_name, run):
    path = f'{PATH_MODELS}/{model_name}_{exp_name}_run{run}.pt'

    model = build_model(model_name)
    ckpt  = torch.load(path, map_location=device, weights_only=False)
    model.load_state_dict(ckpt['model'])
    model.eval()

    return model

def build_unnormalized_confusion_matrix(model, data_loader):
    preds = []
    ground_truth = []

    model.eval()
    with torch.no_grad():

        for images, targets in data_loader:

            logits = model(images.to(device))
            preds_labels = logits.argmax(dim=1).cpu()
            preds.extend(preds_labels.tolist())
            ground_truth.extend(targets.cpu().tolist())

    num_classes = len(data_loader.dataset.classes)
    vcpi_util.show_confusion_matrix(ground_truth, preds, num_classes)

def inverse_normalize(tensor, mean, std):
    for t, m, s in zip(tensor, mean, std):
        t.mul_(s).add_(m)
    return tensor

# %%
def show_bad_preds_v2(model, data_loader, classes, mean=None, std=None):
    k = 0
    iters = 0
    preds = []
    ground_truth = []
    
    # inferir tamanho da imagem a partir do loader
    sample, _ = next(iter(data_loader))
    img_size = sample.shape[-1]  # altura/largura
    
    imgs = torch.zeros(52, 3, img_size, img_size)
    iterator = iter(data_loader)
    max_iters = len(data_loader)
    model.eval()
    with torch.no_grad():
        while k < 52 and iters < max_iters:
            images, targets = next(iterator)
            logits = model(images.to(device))
            predictions = torch.nn.functional.softmax(logits, dim=1).cpu().detach().numpy()
            for i in range(len(predictions)):
                if np.argmax(predictions[i]) != targets[i] and k < 52:
                    preds.append(predictions[i])
                    ground_truth.append(int(targets[i]))
                    img = images[i]
                    if mean is not None and std is not None:
                        img = inverse_normalize(img.clone(), mean, std)
                    imgs[k] = img
                    k += 1
            iters += 1
    vcpi_util.plot_predictions(imgs, preds, ground_truth, classes, 13, 4)

# %%
models_list = [
    ('conv_II','expansao','ConvII - Expansão Massiva'),
    ('vgg16_tl','expansao','VGG16 c/ TL - Expansão Massiva')
#    ('conv_II','expansao','ConvII - Expansão Massiva'),
#    ('vgg16_tl','expansao','VGG16 c/ TL - Expansão Massiva'),
]

# %%
for model_name, exp_name, label in models_list:
    print(f'{"-"*50}')
    print(f'{label}')
    print(f'{"-"*50}')

    test_loader, _ = get_test_loader(model_name)
    model = load_model(model_name, exp_name, 0)
    
    print(f'{"-"*10} Matriz de Confusão {"-"*10}')
    build_unnormalized_confusion_matrix(model, test_loader)
    print(f'{"-"*10} Piores classificações {"-"*10}')
    if model_name == 'conv_II':
        show_bad_preds_v2(model, test_loader, test_loader.dataset.classes)
    else:
        show_bad_preds_v2(model, test_loader, test_loader.dataset.classes, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# Out:
# --------------------------------------------------
# ConvII - Expansão Massiva
# --------------------------------------------------
# ---------- Matriz de Confusão ----------
# ---------- Piores classificações ----------
# --------------------------------------------------
# VGG16 c/ TL - Expansão Massiva
# --------------------------------------------------
# ---------- Matriz de Confusão ----------
# ---------- Piores classificações ----------

# %% [markdown]
# ---
# # Parte 2 – Ensemble

# %% [markdown]
# ## Ensemble configuration

# %%
ENSEMBLE_RUNS = RUNS

transform_ensemble_conv = v2.Compose([
    v2.Resize((IMG_SIZE_CONV, IMG_SIZE_CONV)),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True)
])

transform_ensemble_vgg = v2.Compose([
    v2.Resize((IMG_SIZE_VGG, IMG_SIZE_VGG)),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

def get_test_loader(model_name):
    transform = transform_ensemble_vgg if model_name in ('vgg16', 'vgg16_tl') else transform_ensemble_conv
    test_set = torchvision.datasets.ImageFolder(root=PATH_TEST, transform=transform)
    return torch.utils.data.DataLoader(test_set, batch_size=BATCH_SIZE, shuffle=False), len(test_set)

loader_conv, n_test_conv = get_test_loader('conv_II')
print(f'Test samples (conv_II): {n_test_conv}')
loader_vgg, n_test_vgg = get_test_loader('vgg16')
print(f'Test samples (vgg16/vgg16_tl): {n_test_vgg}')
# Out:
# Test samples (conv_II): 12630
# Test samples (vgg16/vgg16_tl): 12630

# %% [markdown]
# ## Auxiliary functions for ensemble evaluation

# %%
def load_ensemble_models(models_ensemble_list):
    models = []
    accs_conv   = []
    accs_vgg   = []

    for model_name, exp_name, i in models_ensemble_list:
        path = f'{PATH_MODELS}/{model_name}_{exp_name}_run{i}.pt'

        if not os.path.exists(path):
            print(f'  [WARNING] Checkpoint not found: {path} — skipped')
            continue

        model = build_model(model_name)
        ckpt  = torch.load(path, map_location=device, weights_only=False)
        model.load_state_dict(ckpt['model'])
        model.eval()

        #acc = evaluate(model, loader)
        models.append((model_name, model))
        #accs.append(acc)
        #print(f'  Run {i}: accuracy = {acc:.4f}')

    #if accs:
    #    print(f'  Individual mean: {np.mean(accs):.4f}  |  Std: {np.std(accs):.4f}')
    return models




def get_labels_logits_and_preds(models):
    labels  = None
    logits  = []
    preds   = []

    for model_name, model in models:
        loader, _ = get_test_loader(model_name)
        model_logits = []
        model_preds  = []
        batch_labels = []

        with torch.no_grad():
            for inputs, targets in loader:
                inputs = inputs.to(device)
                outputs = model(inputs)
                model_logits.extend(outputs.cpu())
                model_preds.extend(outputs.argmax(dim=1).cpu())
                batch_labels.extend(targets.tolist())

        if labels is None:
            labels = batch_labels
            
        logits.append(model_logits)
        preds.append(model_preds)

    return labels, logits, preds

# %% [markdown]
# ## Soft Voting Ensemble

# %%
def soft_voting_accuracy(labels, logits):
    num_samples = len(logits[0])
    soft_preds  = []
    
    for s in range(num_samples):
        summed = torch.zeros(NUM_CLASSES)
        for run_logits in logits:
            summed += run_logits[s]
        soft_preds.append(torch.argmax(summed).item())
    return sum(y == p for y, p in zip(labels, soft_preds)) / len(labels)

# %% [markdown]
# ## Hard Voting Ensemble

# %%
def hard_voting_accuracy(labels, preds):
    from collections import Counter
    hard_preds = []
    for s in range(len(labels)):
        votes = [preds[r][s].item() for r in range(len(preds))]
        hard_preds.append(Counter(votes).most_common(1)[0][0])
    return sum(y == p for y, p in zip(labels, hard_preds)) / len(labels)

# %% [markdown]
# ## Run Ensemble

# %%
ensembles_to_test = [
    {
        'label': 'conv_II + vgg16_tl (baseline)',
        'models': [('conv_II','baseline',0), ('vgg16_tl','baseline',0)]
    },
    # convII e VGG16 com os vários experimentos
    {
        'label': 'conv_II: baseline + geo + geo2 + color + combined + mix + expansao',
        'models': [('conv_II','baseline',0), ('conv_II','geo',0), ('conv_II','geo2',0), ('conv_II','color',0), ('conv_II','combined',0), ('conv_II','mix',0), ('conv_II','expansao',0)]
    },
    {
        'label': 'vgg16: baseline + geo + geo2 + color + combined + mix + expansao',
        'models': [('vgg16_tl','baseline',0), ('vgg16_tl','geo',0), ('vgg16_tl','geo2',0), ('vgg16_tl','color',0), ('vgg16_tl','combined',0), ('vgg16_tl','mix',0), ('vgg16_tl','expansao',0)]
    },
    # ensembles com os experimentos de melhor performance de cada modelo
    {
        'label': 'conv_II (expansao) + vgg16_tl (expansao)',
        'models': [('conv_II','expansao',0), ('vgg16_tl','expansao',0), ('conv_II','mix',0), ('vgg16_tl','geo',0)]
    },
    # ensembles com os experimentos de pior performance de cada modelo
    {
        'label': 'conv_II (geo) + vgg16_tl (combined)',
        'models': [('conv_II','geo',0), ('vgg16_tl','combined',0)]
    }
]

ensemble_results = []
for ens in ensembles_to_test:
    model_list = load_ensemble_models(ens['models'])
    labels, logits, preds_list = get_labels_logits_and_preds(model_list)
    soft_acc = soft_voting_accuracy(labels, logits)
    hard_acc = hard_voting_accuracy(labels, preds_list)
    ensemble_results.append({
        'Ensemble':          ens['label'],
        'Soft Voting (%)':   round(soft_acc*100, 2),
        'Hard Voting (%)':   round(hard_acc*100, 2),
    })

ensemble_df = pd.DataFrame(ensemble_results)

# %%
ensemble_df
# Out:
#                                             Ensemble  Soft Voting (%)  \
# 0                      conv_II + vgg16_tl (baseline)            96.33
# 1  conv_II: baseline + geo + geo2 + color + combi...            98.57
# 2  vgg16: baseline + geo + geo2 + color + combine...            91.11
# 3           conv_II (expansao) + vgg16_tl (expansao)            97.61
# 4                conv_II (geo) + vgg16_tl (combined)            96.53
#
#    Hard Voting (%)
# 0            97.28
# 1            98.49
# 2            91.01
# 3            98.80
# 4            96.60

# %% [markdown]
# ## Visualization Ensemble Results

# %%
def analyse_ensemble(labels, logits, preds_list, ens_label):
    n_samples = len(labels)

    # transpor preds: [modelo][sample] → [sample][modelo]
    preds_by_sample = [
        [preds_list[r][s].item() for r in range(len(preds_list))]
        for s in range(n_samples)
    ]

    # soft vote por sample
    soft_by_sample = []
    for s in range(n_samples):
        summed = torch.zeros(NUM_CLASSES)
        for run_logits in logits:
            summed += run_logits[s]
        soft_by_sample.append(torch.argmax(summed).item())

    test_loader_vis, _ = get_test_loader('conv_II')
    test_set_vis = test_loader_vis.dataset

    def show_example(idx, title):
        img, _ = test_set_vis[idx]
        img_np = img.permute(1, 2, 0).numpy().clip(0, 1)
        plt.imshow(img_np)
        plt.axis('off')
        plt.title(title)
        plt.show()

    def format_case(idx):
        true = labels[idx]
        return (
            f"Index: {idx}\n"
            f"True label: {true} ({test_set_vis.classes[true]})\n"
            f"Per-model predictions: {preds_by_sample[idx]}\n"
            f"Soft-vote prediction: {soft_by_sample[idx]} ({test_set_vis.classes[soft_by_sample[idx]]})"
        )

    print(f'\n{"="*55}')
    print(f'  {ens_label}')
    print(f'{"="*55}')

    # ensemble corrige pelo menos um modelo errado
    fix_idx = next(
        (i for i in range(n_samples)
         if soft_by_sample[i] == labels[i]
         and any(p != labels[i] for p in preds_by_sample[i])),
        None
    )
    if fix_idx is not None:
        print("\nEnsemble CORRIGE erros:\n")
        print(format_case(fix_idx))
        show_example(fix_idx, f"[{ens_label}] Ensemble corrige pelo menos um modelo")
    else:
        print("Sem exemplos onde o ensemble corrija erros individuais.")

    # maioria (hard) erra, mas pelo menos um modelo acerta
    worsen_idx = next(
        (i for i in range(n_samples)
         if Counter(preds_by_sample[i]).most_common(1)[0][0] != labels[i]
         and any(p == labels[i] for p in preds_by_sample[i])),
        None
    )
    if worsen_idx is not None:
        print("\nEnsemble AMPLIFICA erros:\n")
        print(format_case(worsen_idx))
        show_example(worsen_idx, f"[{ens_label}] Maioria errada, algum modelo acerta")
    else:
        print("Sem exemplos onde o ensemble amplifique erros.")

# %%
for ens in ensembles_to_test:
    model_list = load_ensemble_models(ens['models'])
    labels, logits, preds_list = get_labels_logits_and_preds(model_list)
    soft_acc = soft_voting_accuracy(labels, logits)
    hard_acc = hard_voting_accuracy(labels, preds_list)

    analyse_ensemble(labels, logits, preds_list, ens['label'])
# Out:
# =======================================================
#   conv_II + vgg16_tl (baseline)
# =======================================================
#
# Ensemble CORRIGE erros:
#
# Index: 0
# True label: 0 (00000)
# Per-model predictions: [0, 2]
# Soft-vote prediction: 0 (00000)
# Ensemble AMPLIFICA erros:
#
# Index: 97
# True label: 1 (00001)
# Per-model predictions: [2, 1]
# Soft-vote prediction: 1 (00001)
# =======================================================
#   conv_II: baseline + geo + geo2 + color + combined + mix + expansao
# =======================================================
#
# Ensemble CORRIGE erros:
#
# Index: 50
# True label: 0 (00000)
# Per-model predictions: [4, 0, 0, 0, 0, 0, 0]
# Soft-vote prediction: 0 (00000)
# Ensemble AMPLIFICA erros:
#
# Index: 83
# True label: 1 (00001)
# Per-model predictions: [1, 6, 4, 25, 40, 6, 40]
# Soft-vote prediction: 1 (00001)
# =======================================================
#   vgg16: baseline + geo + geo2 + color + combined + mix + expansao
# =======================================================
#
# Ensemble CORRIGE erros:
#
# Index: 1
# True label: 0 (00000)
# Per-model predictions: [0, 8, 1, 1, 2, 0, 0]
# Soft-vote prediction: 0 (00000)
# Ensemble AMPLIFICA erros:
#
# Index: 36
# True label: 0 (00000)
# Per-model predictions: [2, 4, 2, 0, 2, 2, 4]
# Soft-vote prediction: 2 (00002)
# =======================================================
#   conv_II (expansao) + vgg16_tl (expansao)
# =======================================================
#
# Ensemble CORRIGE erros:
#
# Index: 0
# True label: 0 (00000)
# Per-model predictions: [0, 4, 0, 4]
# Soft-vote prediction: 0 (00000)
# Ensemble AMPLIFICA erros:
#
# Index: 300
# True label: 1 (00001)
# Per-model predictions: [1, 8, 4, 8]
# Soft-vote prediction: 8 (00008)
# =======================================================
#   conv_II (geo) + vgg16_tl (combined)
# =======================================================
#
# Ensemble CORRIGE erros:
#
# Index: 1
# True label: 0 (00000)
# Per-model predictions: [0, 2]
# Soft-vote prediction: 0 (00000)
# Ensemble AMPLIFICA erros:
#
# Index: 512
# True label: 1 (00001)
# Per-model predictions: [12, 1]
# Soft-vote prediction: 1 (00001)
